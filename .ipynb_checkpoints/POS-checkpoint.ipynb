# %%
import Data
import nltk
from Models import nGrams as n

# %%
poems = Data.PoetryFoundationPoems()
poems = Data.Poem_words_dict(poems)

# %%
def word_pos_tags(dic, poems_tagged):
    for word, tag in poems_tagged:
        if(word in dic):
            if(tag in dic[word]): 
                dic[word][tag] = dic[word][tag]+1
            else:
                dic[word][tag] = 1
        else:
            dic[word] = {tag:1}
    return dic

def tag_pos(poem, dic):
    poem = [w.lower() for w in poem]
    nltk_tags = nltk.pos_tag(poem)
    modify_tags = []
    only_tags = []
    for word,tag in nltk_tags:
        if(word == "newline"):
            modify_tags = modify_tags + [(word,"NEWLINE")]
            only_tags = only_tags + ["NEWLINE"]
        else: 
            modify_tags = modify_tags + [(word,tag)]
            only_tags = only_tags + [tag]

    dic = word_pos_tags(dic, modify_tags)
    #print(modify_tags)
    #print()
    return(only_tags, dic)

# %%
poems_of_tags = []
pos_dicts = {}
for p in poems:
    poem_tagged, pos_dicts = tag_pos(p, pos_dicts)
    poems_of_tags = poems_of_tags + [poem_tagged]
    #print(pos_dicts)

# %%
a = Models.nGrams()

# %%
WordsTri = {}
for i in poems:
    WordsTri = a.NGram(WordsTri, i,3)

Words4 = {}
for i in poems:
    Words4 = a.NGram(Words4, i, 4)

# %%
POS3 = {}
for i in poems_of_tags:
    POS3 = a.NGram(POS3, i, 3)

POS4 = {}
for i in poems_of_tags:
    POS4 = a.NGram(POS4, i, 4)

# %%
n.next_word_prob(["ALONG","THAT"], WordsTri, 3, 0)
# Out:
# ('RIVERBANK', 0.25)

# %%
n.next_word_prob(["NN","VB"], POS3, 3, 0)
# Out:
# ('PRP', 0.12964824120603016)

# %%
from Models import nGrams as nn

def nextPOSWord(words, POS_tags_of_words, words_nGram, POS_nGram, POS_dic_words, n):    
    wordsDic    = words_nGram
    POS_Ngram   = POS_nGram
    
    nn.next_word_prob(words, wordsDic, n, 0)

    for word in words:
        wordsDic = wordsDic[word]
        POS_prob(word, POS_dic_words)
        
    for POS_tag in POS_tags_of_words:
        POS_Ngram = POS_Ngram[POS_tag]
        
    Max = 0
    next_word = "Error"
    
    for word,probablity_word in list(wordsDic.items()):
        final_prob = 0
        
        word_POS_p = [POS_dic_words[word].items()]
        
        for tag, prob_tag_given_word in word_POS_p:
            prob_tag_for_tag_sequence = POS_Ngram[tag]
            final_prob = probablity_word * prob_tag_given_word*prob_tag_for_tag_sequence
            
            #print(word,probablity_word,syllaDic[word_syllable_count], final_prob)
            if(final_prob>Max):
                Max = final_prob
                next_word = word
    return(next_word)

# %%
pos_dicts
# Out:
# {'newline': {'NEWLINE': 379146},
#  'dog': {'NN': 812, 'JJ': 24, 'VBZ': 1, 'VB': 2, 'VBP': 4},
#  'bone': {'NN': 515, 'JJ': 7, 'VBN': 1, 'VB': 14, 'CD': 2, 'VBP': 2, 'RB': 3},
#  ',': {',': 275583},
#  'stapler': {'NN': 2},
#  'cribbage': {'NN': 4},
#  'board': {'NN': 160},
#  'garlic': {'JJ': 25, 'NN': 10, 'NNS': 1},
#  'press': {'NN': 148, 'VB': 46, 'VBP': 19, 'JJ': 2, 'VBD': 2, 'VBZ': 1},
#  'because': {'IN': 2243, 'RB': 36, 'VB': 1, 'NN': 2},
#  'this': {'DT': 13889},
#  'window': {'NN': 1150,
#   'JJ': 65,
#   'WRB': 1,
#   'VB': 5,
#   'RB': 1,
#   'VBP': 2,
#   'VBZ': 8,
#   'WP': 1,
#   'IN': 1,
#   'JJS': 1},
#  'is': {'VBZ': 30197},
#  'loose': {'JJ': 249, 'VB': 41, 'RB': 77, 'NN': 13, 'VBP': 8, 'VBD': 2},
#  'lacks': {'NNS': 7, 'VBZ': 23},
#  'suction': {'NN': 14},
#  'grip': {'NN': 73, 'VB': 10, 'VBP': 6, 'JJ': 2},
#  '.': {'.': 158628},
#  'bungee': {'NN': 2},
#  'cord': {'NN': 61, 'VB': 1},
#  'bootstrap': {'NN': 1, 'VB': 1},
#  'leash': {'NN': 32, 'JJ': 5, 'VB': 1},
#  'leather': {'CC': 3,
#   'NN': 151,
#   'RB': 9,
#   'JJ': 4,
#   'RBR': 2,
#   'JJR': 14,
#   'FW': 1,
#   'PRP$': 1},
#  'belt': {'VBD': 8, 'NN': 115, 'VBP': 1},
#  'had': {'VBD': 6613, 'VBN': 133, 'VB': 2, 'NN': 4},
#  'sash': {'VBN': 1, 'NN': 25, 'JJ': 1},
#  'cords': {'NNS': 41},
#  'they': {'PRP': 15388},
#  'frayed': {'VBP': 1, 'JJ': 19, 'VBD': 4, 'VBN': 15},
#  'broke': {'VBD': 385, 'NN': 22, 'RB': 8, 'VBN': 9, 'JJ': 2, 'UH': 1, 'VB': 1},
#  'feather': {'NN': 124,
#   'JJR': 11,
#   'JJ': 7,
#   'RB': 16,
#   'VBP': 1,
#   'RBR': 1,
#   'VB': 3,
#   'PRP$': 1},
#  'duster': {'NN': 2, 'JJ': 1},
#  'thatch': {'NN': 24, 'JJ': 1, 'VB': 1},
#  'of': {'IN': 89611},
#  'straw': {'NN': 106, 'JJ': 57, 'NNS': 1},
#  'empty': {'JJ': 840,
#   'NN': 46,
#   'VB': 22,
#   'RB': 9,
#   'VBD': 2,
#   'VBP': 23,
#   'NNS': 4,
#   'VBZ': 2,
#   'CC': 1,
#   'FW': 3,
#   'VBN': 2,
#   'IN': 1},
#  'bottle': {'NN': 189, 'JJ': 17, 'VBD': 1, 'VBP': 1, 'VB': 1},
#  'elmer': {'NN': 1, 'JJ': 1},
#  "'s": {'POS': 6230, 'VBZ': 1928, 'PRP': 5, 'VB': 1},
#  'glue': {'JJ': 13, 'NN': 43, 'VB': 3, 'VBP': 3},
#  'loud': {'JJ': 321,
#   'NN': 91,
#   'NNS': 1,
#   'VB': 10,
#   'FW': 2,
#   'VBP': 10,
#   'VBZ': 5,
#   'CC': 1,
#   'VBN': 1,
#   'RB': 4},
#  'its': {'PRP$': 8048},
#  'hinges': {'NNS': 45, 'VBZ': 5},
#  'clack': {'VBP': 5, 'JJ': 1, 'NN': 13},
#  'open': {'JJ': 1271,
#   'VB': 250,
#   'VBP': 159,
#   'RP': 8,
#   'NN': 3,
#   'RB': 2,
#   'IN': 1,
#   'VBZ': 2,
#   'VBD': 1},
#  'shut': {'NN': 112,
#   'VB': 45,
#   'VBD': 85,
#   'JJ': 30,
#   'VBN': 91,
#   'VBP': 58,
#   'RB': 8,
#   'PDT': 2,
#   'NNS': 4,
#   'CC': 1,
#   'JJR': 1},
#  'stuffed': {'JJ': 18,
#   'VBD': 14,
#   'VBN': 22,
#   'NN': 38,
#   'VB': 2,
#   'VBP': 9,
#   'CC': 1,
#   'NNS': 1,
#   'RB': 1},
#  'bear': {'NN': 181,
#   'VB': 270,
#   'JJ': 86,
#   'IN': 36,
#   'VBD': 1,
#   'VBP': 84,
#   'JJR': 1},
#  'baby': {'NN': 606,
#   'VB': 9,
#   'JJ': 17,
#   'VBP': 5,
#   'NNS': 1,
#   'FW': 1,
#   'IN': 2,
#   'RP': 2,
#   'VBZ': 1},
#  'blanket': {'NN': 126, 'VBP': 1},
#  'single': {'JJ': 548},
#  'crib': {'NN': 39, 'VBP': 1, 'JJ': 1},
#  'split': {'VBN': 22,
#   'NN': 126,
#   'VBD': 51,
#   'VB': 29,
#   'VBP': 10,
#   'JJ': 11,
#   'VBZ': 1,
#   'PDT': 1},
#  'it': {'PRP': 31566},
#  'dividing': {'VBG': 29, 'NN': 4, 'JJ': 1},
#  'in': {'IN': 62840},
#  'two': {'CD': 3102},
#  'velvet': {'NN': 121, 'JJ': 22, 'RB': 1, 'VB': 1, 'FW': 1, 'IN': 1},
#  'moss': {'NN': 144,
#   'IN': 1,
#   'FW': 5,
#   'RB': 2,
#   'PDT': 1,
#   'NNS': 2,
#   'VB': 3,
#   'RBS': 1},
#  'sagebrush': {'NN': 6, 'JJ': 1},
#  'willow': {'NN': 48, 'JJ': 55, 'VBP': 1, 'IN': 1, 'VB': 2},
#  'branch': {'NN': 224, 'VB': 9, 'JJ': 2, 'VBP': 2},
#  'robin': {'NN': 54, 'JJ': 8, 'VB': 4, 'VBP': 1},
#  'wing': {'NN': 298, 'VBG': 143, 'JJ': 3},
#  'pane': {'NN': 84},
#  'less': {'RBR': 341,
#   'JJR': 596,
#   'NN': 20,
#   'VB': 6,
#   'CC': 36,
#   'RB': 1,
#   'JJS': 4,
#   'VBP': 2,
#   'IN': 2},
#  'only': {'RB': 3798, 'JJ': 635},
#  'a': {'DT': 82717},
#  'frame': {'NN': 271, 'JJ': 4, 'VB': 30, 'VBP': 7, 'RB': 1},
#  'air': {'NN': 2734, 'JJ': 2, 'VBZ': 1, 'RB': 1, 'VBP': 3, 'VB': 2, 'VBN': 1},
#  'the': {'DT': 214508},
#  'old': {'JJ': 4026},
#  'cupola': {'NN': 8},
#  'glinted': {'VBN': 4, 'VBD': 1},
#  'above': {'IN': 1534, 'RB': 12, 'NN': 15, 'VBP': 1, 'VB': 10, 'JJ': 17},
#  'clouds': {'NN': 327,
#   'NNS': 477,
#   'VBZ': 20,
#   'JJ': 50,
#   'VB': 10,
#   'VBP': 12,
#   'VBN': 1,
#   'VBD': 3},
#  'shone': {'JJ': 3,
#   'NN': 100,
#   'VBD': 8,
#   'VBP': 15,
#   'VBZ': 5,
#   'VBN': 4,
#   'RB': 2,
#   'VB': 5},
#  'among': {'IN': 1412},
#  'fir': {'JJ': 15, 'NN': 46, 'VBP': 2, 'VB': 3, 'NNS': 1, 'VBZ': 1},
#  'trees': {'NNS': 1744, 'VBZ': 12, 'JJ': 1, 'VB': 1},
#  'but': {'CC': 16988},
#  'took': {'VBD': 1167},
#  'him': {'PRP': 6596},
#  'an': {'DT': 8635},
#  'hour': {'NN': 910},
#  'for': {'IN': 23493},
#  'half': {'NN': 1057,
#   'PDT': 275,
#   'JJ': 266,
#   'DT': 46,
#   'VBP': 7,
#   'RB': 13,
#   'VBD': 7,
#   'RBR': 3,
#   'VBN': 3,
#   'VB': 10,
#   'VBZ': 4,
#   'MD': 1},
#  'mile': {'IN': 2, 'NN': 96, 'JJ': 22, 'VBN': 1},
#  'all': {'PDT': 3643, 'DT': 12464, 'RB': 51, 'VB': 27, 'VBP': 2, 'JJ': 1},
#  'way': {'NN': 4031},
#  'up': {'IN': 625,
#   'RP': 6277,
#   'RB': 1527,
#   'VB': 2,
#   'NN': 16,
#   'JJ': 5,
#   'VBP': 1},
#  'hill': {'NN': 624, 'JJ': 20, 'RB': 3, 'VB': 11, 'VBZ': 1, 'VBP': 1, 'UH': 1},
#  'as': {'IN': 19992, 'RB': 1604, 'VBP': 1},
#  'he': {'PRP': 20130},
#  'trailed': {'VBD': 19, 'VBN': 6},
#  'village': {'NN': 278, 'JJ': 4, 'VB': 2},
#  'passed': {'VBD': 234, 'VBN': 243},
#  'by': {'IN': 12917},
#  'greeted': {'VBD': 13, 'VBN': 6, 'JJ': 1},
#  'asked': {'VBD': 476, 'VBN': 143, 'VB': 1, 'NNS': 1},
#  'about': {'IN': 3671, 'RB': 159, 'RP': 6, 'NN': 2, 'VBP': 1},
#  'his': {'PRP$': 20217},
#  'health': {'NN': 141},
#  'everybody': {'NN': 147, 'JJ': 6, 'VBP': 1, 'VB': 2},
#  'hurried': {'VBD': 28, 'JJ': 14, 'VBN': 19},
#  'to': {'TO': 72861},
#  'catch': {'VB': 286, 'NN': 80, 'VBP': 86, 'JJ': 1, 'VBZ': 1},
#  'mass': {'NN': 191, 'VBP': 3},
#  'left': {'VBD': 1308,
#   'VBN': 631,
#   'JJ': 237,
#   'VBP': 5,
#   'NN': 235,
#   'VB': 13,
#   'NNS': 5,
#   'JJR': 3,
#   'RB': 2,
#   'IN': 1,
#   'CC': 2,
#   'PDT': 1},
#  'leaning': {'VBG': 138, 'NN': 31, 'JJ': 1},
#  'against': {'IN': 1976},
#  'fences': {'NNS': 76, 'VBZ': 4},
#  'measuring': {'VBG': 21, 'NN': 8, 'JJ': 1},
#  'road': {'NN': 884},
#  'with': {'IN': 28329},
#  'walking': {'VBG': 479, 'NN': 98, 'JJ': 4},
#  'stick': {'NN': 170,
#   'JJ': 82,
#   'VB': 29,
#   'VBP': 24,
#   'NNP': 1,
#   'VBD': 2,
#   'VBZ': 1,
#   'RB': 1},
#  'sculpted': {'VBD': 6, 'JJ': 7, 'VBN': 15},
#  'yearned': {'VBD': 12, 'VBN': 6},
#  'day': {'NN': 4855},
#  'when': {'WRB': 11180},
#  'new': {'JJ': 2769},
#  'church': {'NN': 453, 'VB': 24, 'JJ': 1, 'VBP': 2},
#  'would': {'MD': 5572},
#  'be': {'VB': 13474},
#  'built': {'VBN': 278, 'VBD': 77, 'VBP': 18, 'JJ': 5, 'NN': 6, 'VB': 1},
#  'right': {'JJ': 868,
#   'RB': 535,
#   'NN': 509,
#   'VBD': 33,
#   'VB': 23,
#   'VBN': 4,
#   'VBP': 2},
#  'across': {'IN': 1696, 'VBP': 1, 'RP': 4, 'VB': 4, 'NN': 5},
#  'now': {'RB': 7225},
#  'rises': {'VBZ': 198, 'NNS': 71, 'VBP': 1},
#  'moon': {'NN': 1525, 'VB': 7, 'RB': 11, 'JJ': 3, 'VBP': 1},
#  ':': {':': 15743},
#  'saints': {'NNS': 136, 'VB': 1},
#  'frescoes': {'NNS': 8},
#  'meet': {'VBP': 99,
#   'VB': 372,
#   'NN': 133,
#   'JJ': 11,
#   'VBN': 3,
#   'VBZ': 7,
#   'VBD': 4,
#   'RB': 9,
#   'NNS': 1,
#   'RBS': 1,
#   'JJR': 2,
#   'RBR': 1},
#  'eye': {'NN': 1661},
#  'and': {'CC': 108716},
#  'rain': {'NN': 1433,
#   'VB': 73,
#   'JJ': 14,
#   'VBN': 3,
#   'VBP': 29,
#   'VBZ': 1,
#   'RB': 2},
#  'has': {'VBZ': 4387},
#  'started': {'VBN': 57, 'VBD': 251, 'JJ': 3},
#  'cut': {'VB': 189, 'VBD': 237, 'VBN': 170, 'NN': 290, 'VBP': 10, 'JJ': 19},
#  'through': {'IN': 5895,
#   'RB': 14,
#   'RP': 8,
#   'NN': 1,
#   'VBP': 1,
#   'JJ': 1,
#   'VB': 1},
#  'shingles': {'NNS': 19, 'VBZ': 1},
#  'on': {'IN': 24028},
#  'roof': {'NN': 366,
#   'JJ': 27,
#   'VBZ': 4,
#   'VB': 6,
#   'VBP': 3,
#   'NNS': 2,
#   'VBD': 1},
#  'house': {'NN': 2259},
#  'apple': {'NN': 288},
#  'have': {'VBP': 7377, 'VB': 3115, 'JJ': 9, 'NN': 5, 'VBN': 1},
#  'taken': {'VBN': 506},
#  'over': {'RP': 346,
#   'IN': 4441,
#   'RB': 173,
#   'VB': 9,
#   'NN': 11,
#   'JJR': 1,
#   'JJ': 1,
#   'VBN': 1},
#  'sky': {'NN': 2113,
#   'JJ': 220,
#   'VBP': 9,
#   'VB': 11,
#   'VBZ': 3,
#   'NNS': 1,
#   'VBD': 3,
#   'CC': 1,
#   'RB': 1,
#   'VBN': 1},
#  'sequestered': {'VBD': 5, 'VBN': 4, 'JJ': 5},
#  'gate': {'NN': 317, 'JJ': 5, 'VBP': 2, 'VB': 4},
#  'sidled': {'VBD': 4, 'VBN': 2},
#  'porch': {'NN': 210, 'JJ': 1, 'VBN': 1, 'VBP': 1},
#  'look': {'NN': 950,
#   'VB': 824,
#   'VBP': 747,
#   'VBZ': 5,
#   'CC': 1,
#   'RB': 1,
#   'VBD': 11,
#   'VBN': 3,
#   'JJR': 1},
#  'me': {'PRP': 15234},
#  'under': {'IN': 2638},
#  'hood': {'NN': 86, 'JJ': 1, 'VBD': 1},
#  'that': {'DT': 6384, 'WDT': 9880, 'IN': 16184, 'RB': 23, 'VBN': 1, 'VB': 2},
#  'chevrolet': {'NN': 9},
#  'settled': {'VBD': 43, 'VBN': 61, 'VB': 1, 'JJ': 4},
#  'weeds': {'NNS': 217, 'VBZ': 6},
#  'at': {'IN': 15275},
#  'end': {'NN': 1530, 'VB': 244, 'JJ': 19, 'VBP': 73, 'VBN': 1},
#  'pasture': {'NN': 94, 'VBP': 1},
#  'i': {'NN': 34283,
#   'JJ': 14919,
#   'VB': 5310,
#   'NNS': 2296,
#   'VBP': 2138,
#   'RB': 972,
#   'VBZ': 780,
#   'VBN': 323,
#   'IN': 51,
#   'CC': 176,
#   'VBD': 24,
#   'PRP': 3,
#   "''": 1,
#   'FW': 9,
#   'WDT': 4,
#   'MD': 4,
#   'VBG': 2,
#   'EX': 1,
#   'PDT': 1},
#  "'m": {'VBP': 546},
#  'radiator': {'NN': 14},
#  'spent': {'VBD': 97, 'VBN': 133, 'JJ': 32, 'NN': 61, 'VB': 2, 'VBP': 4},
#  'years': {'NNS': 2281},
#  'bolted': {'VBN': 8, 'VBD': 10, 'JJ': 6},
#  'front': {'NN': 437,
#   'JJ': 145,
#   'RB': 3,
#   'VB': 9,
#   'VBD': 2,
#   'IN': 1,
#   'VBP': 2,
#   'VBZ': 1},
#  'engine': {'NN': 140},
#  'shoving': {'VBG': 16},
#  'forward': {'RB': 249,
#   'NN': 52,
#   'JJ': 6,
#   'VBP': 1,
#   'VBD': 1,
#   'VB': 2,
#   'IN': 1},
#  'into': {'IN': 8225},
#  'wind': {'NN': 2266,
#   'VB': 41,
#   'VBP': 43,
#   'IN': 45,
#   'VBZ': 3,
#   'JJ': 8,
#   'WDT': 3,
#   'RB': 2,
#   'NNS': 2,
#   'FW': 1,
#   'WP': 1,
#   'JJS': 3,
#   'VBN': 1},
#  'whatever': {'WDT': 490,
#   'NN': 49,
#   'IN': 41,
#   'VB': 29,
#   'VBP': 1,
#   'WP': 7,
#   'RB': 5,
#   'VBD': 1},
#  'was': {'VBD': 17729},
#  'those': {'DT': 3341},
#  'days': {'NNS': 1727},
#  'mostly': {'RB': 186},
#  'leaked': {'VBN': 8, 'VBD': 11, 'JJ': 1},
#  'away': {'RP': 312, 'RB': 2838, 'NN': 5, 'JJ': 1, 'VB': 4, 'VBP': 1},
#  'my': {'PRP$': 28805},
#  'cap': {'NN': 121, 'VBP': 3, 'VB': 1},
#  'still': {'RB': 4588},
#  'screwed': {'VBN': 11, 'VBD': 10},
#  'tight': {'JJ': 185,
#   'RB': 17,
#   'NN': 47,
#   'VBD': 17,
#   'VBN': 8,
#   'IN': 2,
#   'VBP': 1,
#   'RP': 1,
#   'VB': 1,
#   'MD': 1},
#  'know': {'VBP': 2986,
#   'VB': 1842,
#   'NN': 48,
#   'VBD': 14,
#   'NNS': 19,
#   'JJ': 25,
#   'FW': 4,
#   'VBN': 2,
#   'RB': 1,
#   'IN': 1,
#   'CD': 1,
#   'VBZ': 3,
#   'NNP': 1},
#  'names': {'NNS': 574, 'JJ': 1, 'VBZ': 11, 'RB': 28},
#  'these': {'DT': 3406},
#  'tattered': {'VBD': 17, 'JJ': 44, 'VBN': 9},
#  'moths': {'NNS': 63},
#  'broken': {'JJ': 523,
#   'VBN': 306,
#   'NN': 71,
#   'VB': 20,
#   'RB': 8,
#   'VBD': 6,
#   'VBZ': 7,
#   'VBP': 7,
#   'IN': 3,
#   'NNS': 2,
#   'JJR': 1,
#   'UH': 1},
#  'grasshoppers': {'NNS': 27},
#  'rest': {'NN': 865,
#   'VB': 228,
#   'VBP': 39,
#   'RB': 5,
#   'JJ': 5,
#   'JJS': 23,
#   'VBN': 6,
#   'RBS': 1,
#   'VBD': 1,
#   'VBZ': 1},
#  'you': {'PRP': 28991},
#  "'ve": {'VBP': 482},
#  'forgotten': {'VBN': 187,
#   'JJ': 104,
#   'VB': 16,
#   'NN': 49,
#   'RB': 11,
#   'VBZ': 3,
#   'VBP': 16,
#   'VBD': 2,
#   'NNS': 9},
#  'behind': {'IN': 1470,
#   'NN': 50,
#   'RP': 56,
#   'VB': 14,
#   'VBP': 2,
#   'RB': 16,
#   'NNS': 1},
#  'silo': {'NN': 11, 'JJ': 2},
#  'mother': {'NN': 2383,
#   'RB': 39,
#   'VB': 15,
#   'CC': 11,
#   'IN': 1,
#   'JJ': 3,
#   'NNS': 2,
#   'PRP': 18,
#   'JJR': 12,
#   'RBR': 1,
#   'VBZ': 1,
#   'PRP$': 4,
#   'VBP': 3},
#  'rabbit': {'NN': 140, 'VBD': 1},
#  'hunches': {'NNS': 8, 'VBZ': 3},
#  'like': {'IN': 14582,
#   'VB': 239,
#   'JJ': 216,
#   'VBP': 133,
#   'NN': 10,
#   'RB': 3,
#   'VBZ': 1},
#  'giant': {'JJ': 191, 'NN': 49},
#  'spider': {'NN': 147, 'VB': 2, 'VBP': 2, 'JJR': 1, 'JJ': 2},
#  'strange': {'JJ': 694, 'NN': 76, 'VB': 14, 'VBP': 11},
#  'calm': {'NNS': 9,
#   'JJ': 160,
#   'NN': 203,
#   'VB': 25,
#   'VBP': 8,
#   'VBN': 11,
#   'RB': 1,
#   'VBZ': 2},
#  'six': {'CD': 502},
#  'tiny': {'JJ': 494, 'VB': 4, 'NN': 10, 'IN': 1, 'VBP': 1, 'RB': 1},
#  'babies': {'NNS': 138, 'VBZ': 2},
#  'beneath': {'NN': 371,
#   'IN': 646,
#   'VBZ': 8,
#   'VB': 26,
#   'VBP': 35,
#   'JJ': 13,
#   'RB': 5,
#   'VBD': 4,
#   'CC': 1},
#  'each': {'DT': 3910},
#  'clamoring': {'VBG': 4, 'NN': 4, 'JJ': 1},
#  'sweet': {'JJ': 1407,
#   'NN': 364,
#   'VBN': 8,
#   'VB': 62,
#   'VBD': 6,
#   'VBZ': 10,
#   'VBP': 14,
#   'RB': 6,
#   'UH': 1,
#   'NNS': 2,
#   'EX': 1,
#   'JJR': 1,
#   'PDT': 1},
#  'syringe': {'NN': 12},
#  'milk': {'NN': 442, 'NNS': 2, 'VBP': 2, 'JJ': 2, 'VB': 8, 'TO': 1, 'VBZ': 1},
#  'may': {'MD': 2831},
#  'sound': {'VB': 61,
#   'NN': 1164,
#   'VBD': 21,
#   'JJ': 165,
#   'VBP': 24,
#   'VBZ': 5,
#   'IN': 3,
#   'VBN': 11,
#   'RB': 4,
#   'CC': 1},
#  'cute': {'NN': 16, 'JJ': 12, 'VB': 2},
#  'reading': {'VBG': 231, 'NN': 120, 'JJ': 1, 'VBP': 1},
#  'from': {'IN': 17644},
#  'your': {'PRP$': 11692},
#  'pulpit': {'NN': 16, 'JJ': 1},
#  'plenty': {'NN': 87, 'JJ': 22, 'RB': 4, 'VBP': 1},
#  'one': {'CD': 10659, 'NN': 1457, 'PRP': 2, 'JJ': 1, 'VB': 1, 'VBP': 1},
#  'small': {'JJ': 1760},
#  'out': {'RP': 5245,
#   'IN': 3708,
#   'RB': 206,
#   'NN': 17,
#   'VB': 11,
#   'JJ': 2,
#   'VBP': 2},
#  'reach': {'NN': 158, 'VB': 230, 'VBP': 123, 'VBZ': 5, 'RB': 1, 'VBN': 1},
#  'knife': {'NN': 291,
#   'NNS': 2,
#   'VB': 6,
#   'VBD': 1,
#   'JJ': 11,
#   'VBP': 1,
#   'FW': 1},
#  'fur': {'JJ': 42,
#   'NN': 129,
#   'VB': 10,
#   'VBZ': 2,
#   'NNS': 1,
#   'RB': 3,
#   'VBP': 1,
#   'VBD': 1},
#  'barging': {'NN': 1},
#  'between': {'IN': 2012},
#  'others': {'NNS': 944},
#  'watched': {'VBD': 377, 'VBN': 80, 'JJ': 6, 'VB': 2, 'VBP': 2},
#  'turret': {'NN': 10, 'JJ': 5},
#  'sand': {'NN': 673, 'JJ': 3, 'VBP': 5, 'VB': 7, 'PDT': 1},
#  'if': {'IN': 8472},
#  'could': {'MD': 4855},
#  'cautioned': {'VBN': 2, 'VBD': 3},
#  'summon': {'VB': 24, 'JJ': 5, 'NN': 9, 'VBP': 11, 'VBN': 2, 'VBZ': 1},
#  'bunnies': {'NNS': 6},
#  'fit': {'VB': 79,
#   'VBP': 49,
#   'VBN': 6,
#   'NN': 131,
#   'JJ': 89,
#   'VBZ': 1,
#   'RB': 1},
#  'belly': {'NN': 46, 'RB': 265, 'JJ': 3, 'VB': 1, 'NNS': 1},
#  'swell': {'NN': 75, 'VB': 38, 'VBP': 27, 'RB': 9, 'JJ': 1, 'VBN': 1},
#  'instead': {'RB': 503},
#  'stood': {'VBD': 821,
#   'NN': 118,
#   'VBN': 47,
#   'RB': 3,
#   'VBZ': 3,
#   'JJ': 12,
#   'VB': 3,
#   'VBP': 7},
#  'frozen': {'JJ': 235,
#   'NN': 32,
#   'VBP': 10,
#   'VBN': 20,
#   'VB': 6,
#   'NNS': 7,
#   'VBD': 1,
#   'VBZ': 2},
#  'wishing': {'VBG': 52, 'NN': 13},
#  'some': {'DT': 4858},
#  'equity': {'NN': 9},
#  'must': {'MD': 2794},
#  'why': {'WRB': 2208},
#  'called': {'VBN': 582, 'VBD': 431, 'JJ': 12, 'VB': 2},
#  'wild': {'JJ': 889,
#   'VBP': 26,
#   'NN': 76,
#   'CD': 1,
#   'VB': 13,
#   'WP': 1,
#   'RB': 2,
#   'VBZ': 3,
#   'VBD': 1,
#   'NNS': 1},
#  'life': {'NN': 4334},
#  'crazed': {'JJ': 11, 'VBN': 15, 'VBD': 4},
#  'emotions': {'NNS': 30},
#  'tangled': {'VBD': 29, 'JJ': 40, 'VBN': 42},
#  'underbrush': {'NN': 8, 'JJ': 13},
#  'within': {'IN': 1004},
#  'us': {'PRP': 6272},
#  'did': {'VBD': 3840},
#  'tell': {'NN': 159,
#   'VBP': 460,
#   'VB': 1436,
#   'RP': 1,
#   'IN': 33,
#   'CC': 8,
#   'RB': 1,
#   'JJ': 2,
#   'VBZ': 2,
#   'VBD': 2},
#  'how': {'WRB': 6490},
#  'smallest': {'JJS': 83, 'NN': 2, 'VB': 1},
#  'black': {'JJ': 3005},
#  'trembling': {'NN': 67, 'VBG': 162, 'JJ': 6},
#  'hopped': {'VBD': 18, 'NNS': 1, 'VBN': 2},
#  'kudzu': {'NN': 4, 'NNS': 1, 'VB': 1, 'JJ': 1},
#  'filigreed': {'VBN': 1, 'VBP': 1, 'NN': 1, 'VBD': 1, 'JJ': 1},
#  'wanting': {'VBG': 216, 'NN': 25, 'VBP': 1, 'JJ': 1},
#  'should': {'MD': 2207},
#  'we': {'PRP': 17500},
#  'talk': {'VB': 297,
#   'NN': 412,
#   'VBP': 125,
#   'VBD': 1,
#   'JJ': 4,
#   'VBN': 1,
#   'VBZ': 1},
#  'animal': {'NN': 166, 'JJ': 131, 'VB': 3, 'VBP': 1, 'VBZ': 2},
#  'heritage': {'NN': 26},
#  'their': {'PRP$': 11687},
#  'species': {'NNS': 87, 'VBZ': 1},
#  'creature': {'NN': 201, 'JJ': 2},
#  'development': {'NN': 25},
#  'what': {'WP': 12064, 'WDT': 136},
#  'do': {'VBP': 3953, 'VB': 1920, 'JJ': 24, 'NNS': 2, 'NN': 30, 'FW': 1},
#  'say': {'VB': 1689, 'VBP': 2251, 'NN': 52, 'JJ': 3, 'FW': 1, 'UH': 2},
#  'form': {'NN': 584,
#   'JJ': 31,
#   'VB': 60,
#   'VBP': 39,
#   'VBD': 2,
#   'RB': 3,
#   'VBN': 3,
#   'VBZ': 2},
#  'focus': {'VB': 24, 'NN': 57, 'JJ': 1, 'VBP': 2, 'RB': 1},
#  'writing': {'VBG': 293, 'NN': 103, 'JJ': 1},
#  'stray': {'NN': 38, 'JJ': 50, 'VB': 22, 'VBP': 16, 'RB': 4},
#  'goes': {'VBZ': 822},
#  'hungry': {'JJ': 240, 'NN': 32, 'VB': 2, 'VBZ': 1},
#  'push': {'VBP': 31,
#   'VB': 68,
#   'NN': 76,
#   'IN': 4,
#   'VBZ': 2,
#   'JJ': 9,
#   'VBD': 1,
#   'VBN': 1},
#  'button': {'NN': 93, 'VB': 5, 'JJ': 4, 'VBP': 2, 'RB': 1},
#  'fly': {'VBP': 162,
#   'VB': 239,
#   'JJ': 33,
#   'NN': 218,
#   'VBN': 5,
#   'VBZ': 5,
#   'VBD': 2,
#   'NNS': 7,
#   'RBR': 1,
#   'RB': 1,
#   'IN': 1},
#  'off': {'IN': 1029,
#   'RP': 1872,
#   'RB': 185,
#   'NN': 35,
#   'JJ': 1,
#   'VBP': 2,
#   'VB': 1},
#  'handle': {'NN': 68, 'VB': 27, 'JJ': 15, 'IN': 1, 'VBP': 2, 'PDT': 1},
#  'skin': {'NN': 820,
#   'JJ': 126,
#   'VBD': 7,
#   'VBZ': 1,
#   'FW': 40,
#   'VBN': 4,
#   'VB': 10,
#   'JJR': 1,
#   'NNS': 1,
#   'VBP': 5},
#  'bones': {'NNS': 706, 'VBZ': 6, 'JJ': 2, 'VB': 1},
#  'bat': {'NN': 97, 'JJ': 2, 'VB': 2, 'VBP': 1},
#  "'re": {'VBP': 494},
#  'alike': {'RB': 95, 'JJ': 5, 'NN': 10, 'VB': 6, 'IN': 19, 'VBP': 1, 'CC': 1},
#  'both': {'DT': 1325, 'CC': 19, 'PDT': 3, 'RB': 1, 'VB': 3, 'NN': 1},
#  'resemble': {'JJ': 12, 'VB': 25, 'VBP': 6},
#  'so': {'RB': 9203, 'IN': 1931, 'VBP': 3, 'CC': 68, 'VB': 1, 'NNS': 1},
#  'fierce': {'JJ': 170,
#   'NN': 60,
#   'VBP': 8,
#   'VB': 10,
#   'VBN': 1,
#   'VBD': 1,
#   'CC': 1},
#  'her': {'PRP$': 13536, 'PRP': 2142, 'VB': 10, 'NN': 19, 'VBN': 1, 'RB': 1},
#  'advocacy': {'NN': 1},
#  'behalf': {'NN': 22, 'JJ': 1},
#  'most': {'RBS': 811, 'JJS': 635, 'VB': 3, 'NN': 1},
#  'vulnerable': {'JJ': 43},
#  'child': {'NN': 1421, 'JJ': 77, 'VBP': 8, 'VB': 6, 'VBZ': 1},
#  'who': {'WP': 9118},
#  "'ll": {'MD': 554},
#  'death': {'NN': 2551},
#  'tempest': {'NN': 51,
#   'JJS': 28,
#   'IN': 2,
#   'JJ': 4,
#   'RB': 3,
#   'VBP': 1,
#   'VB': 1,
#   'CC': 1},
#  'such': {'PDT': 326, 'JJ': 2068, 'VB': 9},
#  'headwind': {'NN': 2},
#  '!': {'.': 11031},
#  'sometimes': {'VBZ': 75, 'RB': 1034, 'VB': 13, 'JJ': 1, 'NNS': 6, 'NN': 1},
#  'requires': {'VBZ': 51},
#  'strength': {'NN': 379},
#  'just': {'RB': 3762},
#  'line': {'NN': 1044},
#  'back': {'RB': 3755, 'NN': 615, 'RP': 370, 'VB': 29, 'JJ': 234, 'VBP': 13},
#  'likely': {'JJ': 88, 'RB': 19},
#  'get': {'VB': 1461, 'NN': 143, 'VBP': 453, 'VBN': 1, 'JJ': 2},
#  'carried': {'VBN': 119, 'VBD': 207, 'JJ': 3},
#  'something': {'NN': 2215},
#  'can': {'MD': 8150},
#  'never': {'RB': 4288},
#  'retract': {'VB': 6, 'NN': 1},
#  'saturated': {'VBN': 10, 'VBD': 2, 'JJ': 2},
#  'ribs': {'NN': 81, 'NNS': 10, 'JJ': 12, 'VBZ': 1, 'VBP': 3, 'VB': 1},
#  'down': {'RP': 3487,
#   'RB': 1788,
#   'IN': 700,
#   'NN': 32,
#   'JJ': 35,
#   'VB': 16,
#   'VBN': 10,
#   'NNS': 1,
#   'CC': 2},
#  'stony': {'NN': 46, 'JJ': 18, 'VB': 3},
#  'word': {'NN': 1410},
#  'ruin': {'NN': 119, 'VB': 46, 'JJ': 21, 'VBP': 7, 'NNS': 1, 'VBZ': 3},
#  'frail': {'JJ': 43, 'NN': 100, 'VBP': 5, 'VB': 3, 'VBN': 1, 'RB': 1},
#  'thing': {'NN': 1742},
#  'argument': {'JJ': 4, 'NN': 114},
#  'whole': {'JJ': 1039, 'NN': 120, 'VBP': 9, 'VB': 3},
#  'fundamental': {'JJ': 14},
#  'difference': {'NN': 175},
#  'wet': {'NN': 273,
#   'JJ': 321,
#   'VB': 15,
#   'IN': 5,
#   'VBP': 22,
#   'NNS': 4,
#   'FW': 1,
#   'WP': 2,
#   'VBZ': 9,
#   'WRB': 2,
#   'EX': 1,
#   'VBD': 3,
#   'VBN': 1,
#   'RB': 3},
#  'dry': {'JJ': 546,
#   'RP': 1,
#   'NN': 51,
#   'VBD': 1,
#   'RB': 1,
#   'IN': 3,
#   'VB': 61,
#   'VBP': 21,
#   'NNS': 3,
#   'VBZ': 1},
#  'are': {'VBP': 12523},
#  'start': {'NN': 135, 'VB': 161, 'VBP': 139, 'JJ': 5, 'VBZ': 5, 'RB': 5},
#  'week': {'NN': 346},
#  'or': {'CC': 15000},
#  'according': {'VBG': 106},
#  'beatles': {'NNS': 9},
#  'creep': {'VBP': 30, 'VB': 25, 'NN': 27, 'JJ': 5, 'VBZ': 2},
#  'nun': {'NN': 25, 'JJ': 7, 'RB': 1, 'NNS': 2},
#  'second': {'JJ': 617,
#   'NN': 41,
#   'VB': 5,
#   'VBD': 3,
#   'RB': 1,
#   'VBP': 3,
#   'PDT': 1,
#   'VBZ': 1},
#  'full': {'JJ': 1536},
#  'kids': {'NNS': 275, 'VBP': 1},
#  'been': {'VBN': 3159},
#  'father': {'NN': 1889,
#   'RB': 116,
#   'JJ': 18,
#   'JJR': 20,
#   'RBR': 2,
#   'VBZ': 6,
#   'CC': 5,
#   'JJS': 1,
#   'VB': 8,
#   'VBP': 4,
#   'PRP$': 1,
#   'VBD': 3,
#   'NNS': 2,
#   'PRP': 1},
#  'sunday': {'NN': 134, 'JJ': 136, 'PDT': 1, 'VBN': 1, 'VB': 1, 'VBD': 1},
#  'missed': {'VBN': 46, 'VBD': 66, 'JJ': 8},
#  'sitting': {'VBG': 403, 'NN': 22, 'JJ': 1},
#  'backyard': {'NN': 91, 'JJ': 6, 'RB': 2, 'IN': 3},
#  'glass': {'NN': 1126, 'NNS': 1, 'VBP': 4, 'VB': 5, 'JJ': 8},
#  'pinot': {'NN': 2, 'JJ': 1},
#  'waiting': {'VBG': 817, 'NN': 38, 'JJ': 1},
#  'arrival': {'NN': 43, 'JJ': 11},
#  'first': {'JJ': 2266,
#   'RB': 911,
#   'VB': 15,
#   'VBN': 2,
#   'VBZ': 1,
#   'VBD': 1,
#   'VBP': 1,
#   'NN': 1},
#  '100s': {'CD': 2},
#  'turning': {'VBG': 437, 'NN': 61, 'JJ': 4},
#  'red': {'JJ': 1933, 'VBN': 33, 'VBD': 66, 'NN': 24, 'VB': 6},
#  'garden': {'NN': 730, 'JJ': 22, 'VB': 7, 'VBP': 3},
#  'lettuce': {'NN': 41, 'VB': 2, 'VBP': 1, 'FW': 1, 'RBR': 1, 'JJ': 1},
#  'grown': {'VBN': 257,
#   'JJ': 110,
#   'NN': 52,
#   'RP': 1,
#   'RB': 3,
#   'VB': 3,
#   'IN': 1,
#   'VBP': 4},
#  'too': {'RB': 3867},
#  'bitter': {'JJ': 253,
#   'NN': 69,
#   'RBR': 2,
#   'VB': 3,
#   'VBP': 3,
#   'RB': 2,
#   'IN': 1,
#   'JJR': 1},
#  'eat': {'VB': 401,
#   'NN': 184,
#   'VBP': 126,
#   'JJ': 15,
#   'FW': 1,
#   'VBD': 8,
#   'VBZ': 2,
#   'CC': 1,
#   'VBN': 1,
#   'RB': 1},
#  'am': {'VBP': 3977},
#  'looking': {'VBG': 997},
#  'bluest': {'JJS': 8},
#  'ever': {'RB': 1996},
#  'seen': {'VBN': 1281},
#  'cerulean': {'NN': 7, 'JJ': 9, 'VB': 2},
#  'blue': {'NN': 825,
#   'JJ': 1427,
#   'VB': 17,
#   'RB': 9,
#   'VBP': 11,
#   'VBD': 4,
#   'IN': 11,
#   'CC': 2,
#   'RP': 1,
#   'VBZ': 7,
#   "''": 1,
#   'NNS': 1,
#   'VBN': 3},
#  'heaven': {'JJ': 174,
#   'NN': 664,
#   'RB': 145,
#   'VBP': 8,
#   'VB': 117,
#   'VBN': 94,
#   'PDT': 3,
#   'PRP': 8,
#   'CD': 1,
#   'VBZ': 3,
#   'EX': 1,
#   'VBD': 1,
#   'NNS': 3},
#  'no': {'DT': 10676, 'RB': 512, 'UH': 11, 'NN': 2, 'IN': 1},
#  'believe': {'VB': 348, 'VBP': 384, 'NN': 3, 'JJ': 9, 'NNS': 3},
#  'witness': {'NN': 117,
#   'JJ': 18,
#   'VB': 37,
#   'IN': 6,
#   'RB': 4,
#   'VBP': 8,
#   'WP': 1},
#  'promised': {'VBN': 47, 'VBD': 54, 'JJ': 21},
#  'absolution': {'JJ': 1, 'NN': 4},
#  'unwritten': {'JJ': 19, 'RB': 1, 'IN': 1},
#  'list': {'NN': 168, 'VBP': 12, 'VBZ': 3, 'VB': 10, 'JJ': 1},
#  'dishes': {'NNS': 85, 'VBZ': 3},
#  'sink': {'NN': 117,
#   'VB': 64,
#   'VBP': 65,
#   'VBN': 1,
#   'VBD': 1,
#   'JJ': 1,
#   'VBZ': 1},
#  'brownie': {'JJ': 2, 'VB': 1, 'NN': 1},
#  'breakfast': {'NN': 127, 'VBN': 3, 'VB': 3, 'VBP': 1, 'JJ': 1},
#  'braless': {'JJ': 2},
#  'invisible': {'JJ': 289, 'VBP': 1, 'NN': 4},
#  'fish': {'JJ': 311, 'NN': 353, 'VBP': 11, 'VB': 23},
#  'swim': {'NN': 65, 'VBP': 47, 'VB': 77, 'JJ': 11, 'VBZ': 4, 'FW': 1},
#  'ghost': {'NN': 390,
#   'VB': 4,
#   'FW': 8,
#   'VBN': 1,
#   'VBP': 3,
#   'VBD': 2,
#   'JJS': 1},
#  'ocean': {'NN': 478,
#   'JJ': 142,
#   'VBP': 6,
#   "''": 1,
#   'IN': 2,
#   'VBZ': 1,
#   'VB': 9,
#   'RP': 1,
#   'RB': 1},
#  'described': {'VBN': 21, 'JJ': 3, 'VBD': 18, 'NN': 1},
#  'waves': {'NNS': 597, 'VBZ': 68, 'VB': 1},
#  'water': {'NN': 3079},
#  'worn': {'NN': 41,
#   'VBN': 118,
#   'VBP': 12,
#   'JJ': 113,
#   'VBZ': 2,
#   'VB': 4,
#   'IN': 1,
#   'VBD': 6,
#   'RB': 1,
#   "''": 1,
#   'WP': 3,
#   'NNS': 1,
#   'WDT': 1,
#   'UH': 1},
#  'rock': {'NN': 638, 'VBP': 12, 'VB': 41, 'JJ': 6, 'VBZ': 1},
#  'soon': {'RB': 1046},
#  'will': {'MD': 7852},
#  'learn': {'VB': 300,
#   'VBP': 126,
#   'RB': 2,
#   'NN': 72,
#   'VBN': 10,
#   'IN': 2,
#   'VBD': 2,
#   'JJ': 16,
#   'PDT': 1,
#   'VBZ': 2,
#   'JJR': 1,
#   'CC': 1},
#  'walk': {'VB': 374,
#   'VBP': 467,
#   'NN': 380,
#   'JJ': 4,
#   'CC': 1,
#   'NNS': 1,
#   'VBD': 1,
#   'VBN': 2,
#   'VBZ': 3},
#  'then': {'RB': 7750},
#  'humans': {'NNS': 76, 'NNPS': 1},
#  'come': {'VB': 1606,
#   'VBP': 933,
#   'VBN': 887,
#   'JJ': 104,
#   'VBD': 6,
#   'NN': 303,
#   'VBZ': 5,
#   'JJR': 1,
#   'MD': 1},
#  'ashore': {'RB': 37, 'NN': 2, 'IN': 1},
#  'paint': {'JJ': 5,
#   'VB': 72,
#   'VBP': 35,
#   'NN': 159,
#   'VBN': 1,
#   'IN': 1,
#   'VBZ': 1},
#  'dreams': {'NNS': 759,
#   'VBZ': 67,
#   'NN': 82,
#   'JJ': 37,
#   'VB': 2,
#   'RB': 4,
#   'VBP': 2,
#   'VBG': 1},
#  'dying': {'VBG': 508, 'NN': 92, 'JJ': 7},
#  'stone': {'NN': 1045,
#   'RB': 5,
#   'JJ': 23,
#   'VBN': 6,
#   'VB': 28,
#   'CD': 1,
#   'VBP': 2,
#   'VBD': 3},
#  'later': {'RB': 687, 'RBR': 58, 'JJ': 37, 'JJR': 7, 'NN': 14},
#  'much': {'RB': 638, 'JJ': 1664, 'VB': 2},
#  'floor': {'NN': 833},
#  'punctuated': {'VBN': 2, 'JJ': 2, 'VBD': 1},
#  'chevy': {'NN': 21, 'VB': 1},
#  'trucks': {'NNS': 74},
#  'carrying': {'VBG': 168, 'NN': 2},
#  'dreamers': {'NNS': 24},
#  '’': {'VBP': 8704,
#   'NNP': 17425,
#   'VBZ': 3860,
#   'NN': 3710,
#   'JJ': 5930,
#   'VBD': 1442,
#   'VB': 1538,
#   'RB': 82,
#   'FW': 146,
#   'CD': 41,
#   'RP': 8,
#   'NNS': 73,
#   'EX': 2,
#   'IN': 88,
#   'CC': 84,
#   'MD': 53,
#   "''": 11,
#   '$': 11,
#   'WDT': 5,
#   'NNPS': 4,
#   'VBN': 20,
#   'PRP': 14,
#   'JJR': 11,
#   'PDT': 6,
#   'POS': 3,
#   'RBR': 1},
#  'decendants': {'NNS': 1},
#  'going': {'VBG': 1247},
#  'store': {'NN': 339, 'VB': 13, 'VBP': 14, 'RB': 3, 'VBD': 2},
#  'don': {'NN': 507,
#   'VBP': 1128,
#   'JJ': 203,
#   'VB': 294,
#   'VBZ': 53,
#   'VBN': 6,
#   'VBD': 2,
#   'CC': 3,
#   'FW': 1,
#   'NNS': 5,
#   'RB': 1},
#  't': {'NN': 7030,
#   'JJ': 1454,
#   'NNS': 603,
#   'RB': 228,
#   'IN': 143,
#   'VB': 189,
#   'VBD': 89,
#   'VBZ': 132,
#   'CC': 11,
#   'NNP': 12,
#   'VBP': 35,
#   'EX': 8,
#   'RP': 14,
#   'PRP': 3,
#   'WDT': 2,
#   'VBN': 3,
#   'MD': 2},
#  'bother': {'VBD': 3,
#   'VB': 16,
#   'NN': 15,
#   'JJR': 4,
#   'PRP$': 1,
#   'JJ': 4,
#   'VBP': 3,
#   'IN': 1,
#   'RB': 1},
#  'earth': {'NN': 2426,
#   'VB': 54,
#   'VBZ': 4,
#   'JJ': 129,
#   'CC': 3,
#   'VBN': 2,
#   'IN': 4,
#   'RB': 11,
#   'VBP': 9},
#  'spirit': {'NN': 770,
#   'FW': 2,
#   'VB': 13,
#   'JJ': 33,
#   'VBP': 3,
#   'VBZ': 2,
#   'VBD': 2,
#   'VBN': 1},
#  'lives': {'VBZ': 261, 'NNS': 564},
#  'here': {'RB': 4479},
#  'she': {'PRP': 11568},
#  'working': {'VBG': 260, 'NN': 18, 'JJ': 14},
#  'story': {'NN': 772},
#  'oldest': {'JJS': 72},
#  'world': {'NN': 3987},
#  'delicate': {'JJ': 158, 'NN': 41, 'VB': 4, 'VBP': 2},
#  'changing': {'VBG': 191, 'NN': 15, 'JJ': 2},
#  'sees': {'VBZ': 344, 'NNS': 62, 'VB': 1, 'NN': 1},
#  'watching': {'VBG': 460, 'NN': 50, 'JJ': 1},
#  'invite': {'VB': 26, 'JJ': 7, 'VBP': 14, 'NN': 3, 'PDT': 2, 'RB': 1},
#  'coffee': {'NN': 400, 'VBP': 2, 'VBZ': 1, 'VB': 4, 'JJ': 2},
#  'give': {'VB': 1028, 'VBP': 431, 'NN': 46, 'JJ': 72, 'CD': 2},
#  'warm': {'JJ': 506,
#   'VB': 55,
#   'NN': 135,
#   'VBN': 2,
#   'VBD': 2,
#   'VBP': 15,
#   'IN': 5,
#   'VBZ': 6,
#   'WDT': 1},
#  'bread': {'NN': 360,
#   'JJ': 64,
#   'VB': 10,
#   'VBP': 3,
#   'RP': 1,
#   'IN': 1,
#   'VBN': 1,
#   'VBD': 1},
#  'obligated': {'VBN': 3, 'JJ': 1},
#  'stay': {'VB': 417,
#   'NN': 172,
#   'VBP': 117,
#   'JJ': 8,
#   'RB': 1,
#   'VBN': 3,
#   'VBZ': 1,
#   'NNS': 1,
#   'VBD': 1},
#  'listen': {'VB': 238,
#   'NN': 125,
#   'VBP': 99,
#   'VBZ': 19,
#   'VBN': 19,
#   'JJ': 30,
#   'VBD': 2,
#   'NNS': 4,
#   'FW': 1,
#   'RB': 14,
#   'CC': 4},
#  'ordinary': {'JJ': 160, 'VBP': 1, 'NN': 1},
#  'endure': {'VB': 62, 'NN': 37, 'RB': 1, 'VBP': 10, 'JJ': 3},
#  'earthquakes': {'NNS': 11, 'VBZ': 1},
#  'lightning': {'NN': 180, 'VBG': 129, 'VB': 1, 'JJ': 4},
#  'deaths': {'NNS': 102, 'VBZ': 1, 'VB': 1},
#  'love': {'VBP': 917,
#   'NN': 3515,
#   'RBR': 13,
#   'VB': 1280,
#   'JJ': 72,
#   'FW': 4,
#   'IN': 90,
#   'VBD': 14,
#   'JJR': 27,
#   'VBZ': 2,
#   'VBN': 36,
#   'PRP': 2,
#   'RB': 18,
#   'CC': 16,
#   'CD': 1,
#   'NNS': 3,
#   'EX': 2,
#   'PDT': 1},
#  'blinding': {'JJ': 7, 'VBG': 36, 'NN': 19},
#  'beauty': {'NN': 983, 'JJ': 13, 'VBP': 8, 'VB': 9, 'VBN': 1},
#  's': {'PRP': 438,
#   'VBD': 2158,
#   'VBZ': 2385,
#   'NN': 9485,
#   'JJ': 3648,
#   'VB': 615,
#   'VBP': 259,
#   'JJR': 77,
#   'RB': 445,
#   'NNS': 241,
#   'PDT': 158,
#   'RBR': 21,
#   'MD': 17,
#   'FW': 44,
#   'NNP': 9,
#   'CC': 23,
#   'IN': 4,
#   'VBN': 2},
#  'compelling': {'JJ': 1, 'VBG': 6, 'NN': 3},
#  'want': {'VB': 336, 'VBP': 1608, 'JJ': 31, 'NN': 126},
#  'leave': {'VB': 614,
#   'VBP': 649,
#   'JJ': 15,
#   'NN': 43,
#   'NNS': 2,
#   'CC': 2,
#   'VBN': 5,
#   'JJR': 1},
#  ';': {':': 22173},
#  'traps': {'VBZ': 5, 'NNS': 36, 'JJ': 1, 'VB': 1, 'VBP': 1},
#  'see': {'VB': 2947,
#   'VBP': 1672,
#   'NN': 238,
#   'JJ': 10,
#   'VBN': 1,
#   'NNS': 4,
#   'CC': 1,
#   'VBD': 1},
#  'finger': {'NN': 328,
#   'VB': 7,
#   'JJR': 11,
#   'VBZ': 2,
#   'PDT': 1,
#   'RB': 3,
#   'VBP': 3,
#   'JJ': 2,
#   'RBR': 1},
#  'there': {'EX': 6833, 'RB': 3614, 'VB': 8, 'JJ': 3},
#  'escaped': {'VBD': 37, 'VBN': 34, 'JJ': 2, 'NNS': 1},
#  'anything': {'NN': 741},
#  'central': {'JJ': 100},
#  'orchards': {'NNS': 46},
#  'flung': {'VBN': 14,
#   'VBP': 34,
#   'JJ': 20,
#   'NN': 59,
#   'VBD': 31,
#   'VBZ': 8,
#   'VB': 2,
#   'NNS': 1,
#   'RB': 2},
#  'land': {'NN': 1141,
#   'VBP': 28,
#   'VB': 36,
#   'JJ': 2,
#   'RB': 3,
#   'CC': 1,
#   'VBZ': 1,
#   'JJR': 1},
#  'urban': {'JJ': 40},
#  'forests': {'NNS': 121, 'VBZ': 3, 'VB': 2},
#  'rustic': {'JJ': 24},
#  'plantations': {'NNS': 4},
#  'knee': {'VBP': 5, 'NN': 176, 'VB': 14, 'JJ': 13, 'VBD': 1, 'RB': 1},
#  'high': {'JJ': 1782,
#   'NN': 35,
#   'VB': 17,
#   'VBP': 14,
#   'RB': 14,
#   'VBZ': 3,
#   'PDT': 1},
#  'hills': {'NNS': 587, 'VBZ': 16, 'VB': 1, 'NN': 1, 'JJ': 1},
#  'place': {'JJ': 1, 'NN': 2176, 'VBP': 31, 'VB': 53},
#  'elm': {'NN': 62, 'JJ': 10, 'VB': 1},
#  'grove': {'NN': 108, 'VB': 8, 'JJ': 3, 'VBZ': 1},
#  'adcock': {'NN': 2},
#  'corner': {'NN': 480, 'JJ': 1, 'VBD': 1, 'JJR': 1, 'NNS': 1},
#  'book': {'NN': 832},
#  'farm': {'NN': 157, 'JJ': 1, 'VB': 2},
#  'concur': {'VBP': 2},
#  'rush': {'NN': 126,
#   'JJ': 17,
#   'VB': 26,
#   'VBP': 28,
#   'VBZ': 2,
#   'VBN': 1,
#   'VBD': 1},
#  'level': {'NN': 156, 'VB': 5, 'JJ': 20, 'VBP': 2, 'RB': 2, 'VBD': 1},
#  'beating': {'VBG': 113, 'NN': 76, 'JJ': 5},
#  'themselves': {'PRP': 826},
#  'eyes': {'NNS': 4067,
#   'VBZ': 18,
#   'VBP': 7,
#   'VB': 15,
#   'IN': 4,
#   'NN': 1,
#   'JJ': 13,
#   'DT': 1,
#   'RB': 8,
#   'FW': 1,
#   'VBD': 3,
#   'VBN': 2},
#  'which': {'WDT': 6553},
#  'enough': {'JJ': 325,
#   'RB': 951,
#   'NN': 43,
#   'VBN': 5,
#   'VB': 1,
#   'IN': 8,
#   'VBD': 1,
#   'VBZ': 1,
#   'CC': 2,
#   'VBP': 1},
#  'thank': {'NN': 138,
#   'JJ': 10,
#   'VB': 73,
#   'IN': 20,
#   'VBP': 19,
#   'VBD': 22,
#   'CC': 5},
#  'more': {'JJR': 2991, 'RBR': 2684},
#  'scenery': {'NN': 26, 'JJ': 5},
#  'mingled': {'VBN': 32, 'VBD': 25, 'JJ': 11},
#  'darkness': {'JJ': 63, 'NN': 754, 'VB': 28, 'RB': 6},
#  'damp': {'NN': 77,
#   'JJ': 88,
#   'NNS': 4,
#   'VB': 7,
#   'IN': 3,
#   'VBZ': 1,
#   'RB': 2,
#   'VBP': 3},
#  'plains': {'NNS': 132, 'VBZ': 8},
#  'overgrown': {'JJ': 18, 'NN': 5, 'RB': 2, 'IN': 6, 'VBN': 5, 'VBP': 1},
#  'suburbs': {'NNS': 16, 'NN': 23, 'JJ': 11},
#  'places': {'NNS': 373, 'VBZ': 15},
#  'known': {'VBN': 606, 'JJ': 32, 'VB': 7, 'VBP': 2, 'VBZ': 2, 'NN': 2},
#  'civic': {'JJ': 12, 'NN': 7, 'VBP': 1, 'VB': 1, 'NNS': 1},
#  'pride': {'NN': 361,
#   'JJ': 11,
#   'VBP': 3,
#   'VBN': 1,
#   'VB': 8,
#   'RB': 10,
#   'IN': 3},
#  'civil': {'JJ': 93},
#  'obscurity': {'NN': 15},
#  'connected': {'VBN': 32, 'VBD': 8},
#  'version': {'NN': 98},
#  'america': {'JJ': 69,
#   'VB': 18,
#   'NN': 269,
#   'RB': 11,
#   'VBN': 3,
#   'VBP': 4,
#   'NNS': 2,
#   'IN': 12,
#   'FW': 1,
#   'VBZ': 2,
#   'VBD': 1,
#   'PDT': 1},
#  'juice': {'NN': 132, 'VB': 1, 'RB': 1, 'JJ': 1},
#  'elsewhere': {'RB': 126, 'VB': 1},
#  'morning': {'NN': 1668},
#  'walked': {'VBD': 484, 'VBN': 81, 'JJ': 7},
#  'room': {'NN': 1722},
#  'after': {'IN': 3226},
#  'crosshatched': {'VBD': 1, 'JJ': 3},
#  'backward': {'NN': 55,
#   'RB': 45,
#   'VB': 4,
#   'VBP': 1,
#   'JJ': 9,
#   'IN': 1,
#   'VBN': 1,
#   'CC': 1},
#  'glances': {'NNS': 51, 'VBZ': 8},
#  'light': {'JJ': 1554,
#   'NN': 2845,
#   'VB': 49,
#   'VBD': 155,
#   'VBN': 12,
#   'VBZ': 2,
#   'RB': 2,
#   'VBP': 5,
#   'IN': 1,
#   'MD': 1},
#  'unfamiliar': {'JJ': 32, 'NN': 5, 'VBP': 1},
#  'our': {'PRP$': 9015},
#  'doing': {'VBG': 358},
#  'material': {'NN': 51, 'JJ': 24, 'VB': 1},
#  'lumber': {'NN': 15, 'JJ': 5, 'VBP': 2, 'RB': 1, 'VB': 3},
#  'were': {'VBD': 6946},
#  'counting': {'VBG': 83, 'NN': 29, 'JJ': 1},
#  'mood': {'NN': 147},
#  'crossed': {'JJ': 14, 'VBD': 117, 'VBN': 87},
#  'girders': {'NNS': 18},
#  'cool': {'JJ': 305,
#   'VBP': 13,
#   'NN': 127,
#   'VB': 20,
#   'NNS': 1,
#   'VBZ': 3,
#   'VBN': 1,
#   'CC': 1},
#  'downtown': {'NN': 23,
#   'JJ': 17,
#   'VBN': 4,
#   'RP': 3,
#   'RB': 2,
#   'VBZ': 1,
#   'IN': 1,
#   'NNS': 1,
#   'VBP': 1},
#  'shadow': {'NN': 771,
#   'JJ': 101,
#   'VB': 11,
#   'VBZ': 6,
#   'VBP': 6,
#   'VBD': 4,
#   'VBN': 2,
#   'RB': 2},
#  'seized': {'VBN': 27, 'VBD': 26, 'JJ': 3},
#  'again': {'RB': 3198},
#  'braid': {'VBD': 11, 'NN': 27, 'VB': 8, 'VBN': 3},
#  'own': {'JJ': 2969, 'VB': 47, 'VBP': 42, 'IN': 7},
#  'snapped': {'VBD': 41, 'JJ': 3, 'VBN': 16},
#  'perceptions': {'NNS': 6, 'VBZ': 1},
#  'things': {'NNS': 2591},
#  'private': {'JJ': 191},
#  'always': {'RB': 2078},
#  'where': {'WRB': 7956},
#  'turns': {'NNS': 109, 'VBZ': 476, 'RP': 2, 'JJ': 2, 'VBN': 1},
#  'event': {'NN': 132},
#  'destined': {'VBN': 19, 'VBD': 8, 'JJ': 5},
#  'bloom': {'VB': 37, 'NN': 235, 'VBP': 9},
#  'golden': {'JJ': 692},
#  'chimes': {'NNS': 42, 'VBZ': 4},
#  'released': {'VBN': 94, 'VBD': 7, 'JJ': 1},
#  'city': {'NN': 1389},
#  'highest': {'JJS': 136},
#  'tower': {'NN': 245, 'VBP': 5, 'JJR': 18, 'IN': 1, 'VB': 10},
#  'quirky': {'JJ': 3},
#  'happen': {'VBP': 24,
#   'VB': 212,
#   'NN': 22,
#   'VBD': 3,
#   'JJ': 11,
#   'RB': 2,
#   'VBZ': 1,
#   'NNS': 1,
#   'VBN': 1},
#  'instantly': {'RB': 43},
#  'mean': {'VBP': 444,
#   'VB': 238,
#   'JJ': 131,
#   'NN': 168,
#   'VBN': 4,
#   'PRP': 1,
#   'CC': 2,
#   'VBZ': 2,
#   'RBR': 1},
#  'remote': {'VBP': 18, 'JJ': 42, 'NN': 34, 'VB': 8, 'VBZ': 1, 'CC': 1},
#  'orchard': {'RB': 7, 'NN': 100, 'IN': 1, 'JJ': 4},
#  'reached': {'VBN': 60, 'VBD': 124, 'VB': 1},
#  'winding': {'VBG': 88, 'NN': 28, 'JJ': 8},
#  'roads': {'NNS': 215, 'NN': 5, 'JJ': 1, 'VBP': 1, 'VBZ': 10},
#  'hides': {'NNS': 46, 'VBZ': 71, 'JJ': 1, 'NN': 1, 'IN': 1},
#  'them': {'PRP': 7221},
#  'roots': {'NNS': 314, 'JJ': 4, 'VBZ': 3, 'VBN': 1, 'VB': 2},
#  'lumps': {'NNS': 25, 'RB': 1},
#  'trials': {'NNS': 14},
#  'whether': {'IN': 445},
#  'shall': {'MD': 2755},
#  'fate': {'NN': 382, 'JJ': 20, 'VB': 28, 'VBP': 9, 'RBR': 1, 'VBN': 1},
#  'exemplary': {'JJ': 6},
#  'star': {'NN': 698, 'VB': 9, 'VBP': 3, 'JJ': 7, 'VBD': 3, 'VBZ': 2},
#  'letter': {'NN': 310},
#  'arrives': {'VBZ': 80, 'NNS': 16},
#  'exasperation': {'NN': 6},
#  'until': {'IN': 1585},
#  'finally': {'RB': 439},
#  'ripped': {'VBN': 26, 'VBD': 65, 'JJ': 8, 'NN': 2},
#  'not': {'RB': 18719},
#  'knowing': {'VBG': 378, 'NN': 70, 'JJ': 3},
#  'envelope': {'NN': 51, 'VBP': 1, 'JJ': 1},
#  'halves': {'NNS': 31, 'VBZ': 1},
#  'lying': {'VBG': 323, 'NN': 49, 'JJ': 5},
#  'plate': {'NN': 184, 'VB': 5, 'JJ': 2},
#  'message': {'NN': 159},
#  'wise': {'JJ': 50,
#   'NN': 310,
#   'VB': 21,
#   'IN': 3,
#   'VBP': 12,
#   'RB': 11,
#   'VBN': 3,
#   'CC': 1},
#  'seemingly': {'RB': 26},
#  'dictated': {'VBD': 1, 'VBN': 4, 'JJ': 2},
#  'long': {'JJ': 2307,
#   'RB': 1753,
#   'VBN': 1,
#   'CD': 2,
#   'VB': 17,
#   'NN': 4,
#   'VBD': 4,
#   'IN': 4,
#   'VBP': 1},
#  'time': {'NN': 5264},
#  'ago': {'RB': 539, 'IN': 76},
#  'arrived': {'VBN': 75, 'VBD': 96, 'JJ': 2},
#  'telling': {'VBG': 226, 'NN': 25, 'JJ': 5},
#  'danger': {'NN': 156, 'JJR': 2, 'VB': 5, 'JJ': 1, 'RBR': 1, 'RB': 1},
#  'limited': {'JJ': 32, 'VBD': 5, 'VBN': 10},
#  'steps': {'NNS': 402, 'VBZ': 34, 'VB': 1, 'VBD': 1, 'NN': 1},
#  'future': {'NN': 436, 'JJ': 185, 'VB': 5, 'VBP': 1},
#  'yards': {'NNS': 72},
#  'quiet': {'JJ': 619,
#   'VB': 18,
#   'NN': 57,
#   'VBZ': 2,
#   'VBP': 2,
#   'PDT': 1,
#   'RB': 1},
#  'houses': {'NNS': 453},
#  'country': {'NN': 798},
#  'fenced': {'JJ': 5, 'VBN': 11, 'VBD': 8},
#  'areas': {'NNS': 18},
#  'shady': {'JJ': 49, 'NN': 1},
#  'streets': {'NNS': 532, 'VBZ': 9, 'VB': 1},
#  'consider': {'VBP': 38, 'VB': 128, 'NN': 16, 'JJR': 3, 'JJ': 1},
#  'hydrangea': {'NN': 7, 'JJ': 1},
#  'salt': {'NN': 413,
#   'VB': 14,
#   'JJ': 34,
#   'VBP': 3,
#   'VBD': 7,
#   'RB': 2,
#   'VBN': 2,
#   'VBZ': 1,
#   'JJR': 1},
#  'plant': {'NN': 243},
#  'varietal': {'NN': 1},
#  'question': {'NN': 349, 'VB': 13, 'VBP': 5, 'JJ': 1, 'VBZ': 1},
#  'varietals': {'NNS': 2},
#  'diet': {'NN': 23, 'JJ': 20, 'VB': 1},
#  'every': {'DT': 2881},
#  '5': {'CD': 285},
#  'pounds': {'NNS': 70, 'VBZ': 4},
#  'feels': {'NNS': 112,
#   'VBZ': 195,
#   'VBP': 2,
#   'NN': 4,
#   'JJ': 3,
#   'VB': 3,
#   'RB': 1},
#  '20': {'CD': 56},
#  'lost': {'VBN': 1125,
#   'VBD': 382,
#   'JJ': 106,
#   'NN': 43,
#   'VB': 11,
#   'FW': 1,
#   'VBZ': 1,
#   'RB': 2,
#   'JJS': 2,
#   'JJR': 1},
#  '…': {'NN': 14,
#   'NNP': 17,
#   'JJ': 11,
#   'RB': 1,
#   'VBP': 9,
#   'VBD': 2,
#   'PDT': 1,
#   'IN': 2,
#   'MD': 1,
#   'VBZ': 3,
#   'FW': 1,
#   'VBN': 1,
#   'VB': 1},
#  'yes': {'UH': 590,
#   'NNS': 116,
#   'JJ': 4,
#   'RB': 107,
#   'VBZ': 3,
#   'NN': 26,
#   'CC': 3,
#   'VBP': 4,
#   'VB': 7,
#   'JJR': 1,
#   'IN': 3,
#   'FW': 1,
#   'PDT': 2,
#   'CD': 2},
#  'sense': {'NN': 775, 'VBN': 2, 'VB': 35, 'JJ': 3, 'VBP': 11},
#  'possible': {'JJ': 283},
#  'external': {'NN': 1, 'JJ': 17},
#  'occurs': {'VBZ': 25, 'NNS': 8, 'NN': 1, 'IN': 1},
#  'surface': {'NN': 352, 'VB': 7, 'VBP': 5, 'JJ': 2},
#  'plants': {'NNS': 154},
#  'sun': {'NN': 2685,
#   'NNS': 4,
#   'JJ': 111,
#   'VB': 37,
#   'VBZ': 7,
#   'VBP': 5,
#   'VBN': 5,
#   'VBD': 9,
#   'JJR': 1},
#  'darkens': {'VBZ': 23, 'NNS': 16, 'VBP': 1},
#  'beautiful': {'JJ': 836, 'NN': 134, 'VBP': 6, 'VB': 4, 'IN': 3, 'VBZ': 1},
#  '(': {'(': 4568},
#  'obvious': {'JJ': 86},
#  'everything': {'NN': 1352},
#  'hand': {'NN': 3039},
#  'swells': {'NNS': 61, 'VBZ': 35},
#  'bite': {'NN': 64, 'VB': 49, 'JJ': 16, 'VBP': 14, 'RB': 7, 'RP': 1, 'IN': 1},
#  '[': {'NNP': 278,
#   'VB': 21,
#   'JJ': 139,
#   'NN': 155,
#   'CC': 4,
#   'VBN': 1,
#   '$': 24,
#   'VBP': 26,
#   'IN': 17,
#   'VBZ': 17,
#   'VBD': 13,
#   'RB': 3,
#   'NNS': 6,
#   'RBR': 1,
#   'CD': 2,
#   'PDT': 4,
#   'JJR': 2,
#   'RP': 1},
#  'spread': {'VBD': 69, 'JJ': 34, 'VB': 56, 'VBP': 75, 'NN': 160, 'VBN': 39},
#  ']': {'NNP': 264,
#   'JJ': 170,
#   'NN': 125,
#   'FW': 8,
#   'VBP': 52,
#   'CD': 3,
#   'RB': 3,
#   'CC': 10,
#   'VB': 34,
#   'IN': 4,
#   'VBZ': 5,
#   'NNS': 9,
#   'VBD': 4,
#   'RP': 1},
#  'insect': {'JJ': 31, 'NN': 32, 'VB': 2, 'VBP': 1},
#  'venom': {'NN': 23, 'JJ': 4, 'IN': 1, 'VBP': 1},
#  'appears': {'VBZ': 209},
#  'feel': {'VB': 774, 'VBP': 523, 'VBN': 1, 'NN': 205, 'JJ': 2, 'VBD': 1},
#  'nothing': {'NN': 2919},
#  'smashes': {'VBZ': 3, 'NNS': 6, 'JJ': 1},
#  'skull': {'NN': 184, 'JJ': 53, 'VBZ': 2, 'VBP': 1, 'VB': 2},
#  'screams': {'VBZ': 12,
#   'NNS': 59,
#   'JJ': 9,
#   'NN': 16,
#   'VBP': 1,
#   'FW': 1,
#   'VBD': 1},
#  'hold': {'VBP': 357, 'VB': 594, 'NN': 173, 'VBN': 3, 'JJ': 6, 'VBD': 3},
#  'lap': {'NN': 137, 'JJ': 35, 'VBP': 11, 'VB': 4, 'VBZ': 4, 'VBD': 1, 'FW': 1},
#  'kitchen': {'NN': 430, 'VBZ': 1, 'JJ': 9, 'VB': 3, 'NNS': 1, 'FW': 2},
#  'freezer': {'NN': 16, 'JJ': 1},
#  'pressing': {'VBG': 76, 'NN': 5, 'JJ': 2},
#  'pack': {'NN': 122, 'VB': 21, 'JJ': 4, 'VBP': 12, 'VBZ': 1},
#  'clay': {'NN': 269, 'VBN': 4, 'VB': 6, 'VBP': 1, 'NNS': 1, 'JJ': 2, 'VBD': 1},
#  'forehead': {'NN': 162, 'JJ': 43, 'VB': 2, 'VBN': 1},
#  'likes': {'VBZ': 75, 'NNS': 35, 'IN': 1},
#  'cold': {'NN': 409,
#   'JJ': 1129,
#   'VBN': 30,
#   'VBD': 25,
#   'VBP': 24,
#   'RB': 9,
#   'VB': 17,
#   'CC': 1,
#   'NNS': 2,
#   'EX': 1},
#  'move': {'NN': 209, 'VB': 330, 'VBP': 219, 'JJ': 1, 'IN': 5, 'CC': 1},
#  'pushing': {'VBG': 105},
#  'stroller': {'NN': 9},
#  'hauling': {'NN': 4, 'VBG': 23},
#  'also': {'RB': 983},
#  'lifting': {'VBG': 134, 'NN': 19, 'JJ': 1},
#  'having': {'VBG': 710},
#  'another': {'DT': 2267},
#  'body': {'NN': 2648, 'JJ': 3, 'VB': 4, 'VBP': 1},
#  'adjunct': {'JJ': 2, 'NN': 3},
#  'composed': {'VBD': 16, 'VBN': 31, 'JJ': 11},
#  'errand': {'NN': 16},
#  'weight': {'NN': 370,
#   'JJ': 29,
#   'VBD': 18,
#   'JJR': 1,
#   'RB': 1,
#   'VB': 1,
#   'VBN': 1},
#  'tenderness': {'NN': 70, 'JJ': 7, 'RB': 1, 'VB': 2},
#  'amount': {'NN': 39, 'VB': 3},
#  'power': {'NN': 881},
#  'imagine': {'VBP': 107, 'VB': 229, 'NN': 100, 'JJ': 28, 'VBZ': 1},
#  'interfering': {'VBG': 4, 'NN': 1},
#  'twitch': {'NN': 18, 'VB': 9, 'VBP': 5},
#  'muscle': {'NN': 126, 'VBN': 1, 'VB': 1, 'VBZ': 1},
#  'object': {'NN': 101, 'JJ': 32, 'VBP': 5, 'VB': 5},
#  'confusing': {'VBG': 9, 'JJ': 5, 'NN': 1},
#  'middle': {'JJ': 202, 'NN': 258, 'VB': 7, 'VBZ': 1, 'RB': 1},
#  'aged': {'VBN': 67, 'VBD': 22, 'JJ': 23, 'VBP': 1},
#  'little': {'JJ': 3382,
#   'RB': 71,
#   'VBP': 4,
#   'JJR': 1,
#   'VB': 3,
#   'NN': 1,
#   'VBD': 1,
#   'VBZ': 1},
#  'spare': {'JJ': 59, 'NN': 23, 'VBP': 15, 'VB': 67, 'VBZ': 2, 'VBD': 1},
#  'flesh': {'NN': 473,
#   'JJ': 369,
#   'VB': 21,
#   'VBZ': 3,
#   'NNS': 8,
#   'VBP': 5,
#   'RB': 4,
#   'VBD': 1,
#   'VBN': 1},
#  'inch': {'NN': 117, 'JJ': 16, 'VBP': 6, 'VB': 1},
#  'major': {'JJ': 70},
#  'pulling': {'VBG': 145, 'NN': 4},
#  'gravity': {'NN': 124, 'VB': 2},
#  'sleeping': {'VBG': 301, 'NN': 78, 'JJ': 11, 'VBP': 1},
#  'thinking': {'VBG': 426, 'NN': 246, 'VB': 1},
#  'let': {'VB': 2418,
#   'NN': 560,
#   'VBP': 188,
#   'VBN': 36,
#   'VBD': 220,
#   'JJ': 45,
#   'FW': 3,
#   'VBZ': 7,
#   'CC': 12,
#   'RBR': 2,
#   'IN': 3,
#   'RB': 1},
#  'man': {'NN': 5054},
#  'stop': {'NN': 221,
#   'VB': 472,
#   'JJ': 35,
#   'VBP': 60,
#   'PDT': 1,
#   'VBZ': 1,
#   'VBD': 3,
#   'VBN': 1,
#   'RB': 2,
#   'CC': 1},
#  'brush': {'VB': 43,
#   'NN': 130,
#   'IN': 4,
#   'JJ': 11,
#   'VBP': 21,
#   'RB': 1,
#   'VBD': 1,
#   'FW': 2},
#  'drowsy': {'NN': 24, 'JJ': 16, 'VB': 1, 'NNS': 1},
#  'face': {'NN': 2820, 'VB': 82, 'VBP': 91, 'JJ': 4, 'VBN': 2, 'VBZ': 1},
#  'barely': {'RB': 212, 'JJ': 1},
#  'considers': {'VBZ': 15, 'NNS': 9},
#  'around': {'IN': 1719, 'RB': 303, 'RP': 102, 'VB': 5},
#  'perhaps': {'RB': 800},
#  'missing': {'VBG': 205, 'JJ': 5, 'NN': 7},
#  'subtle': {'JJ': 102, 'NN': 12, 'CC': 1},
#  'differentiation': {'NN': 2},
#  'therefore': {'RB': 213,
#   'NN': 44,
#   'IN': 34,
#   'VB': 21,
#   'VBP': 4,
#   'VBD': 1,
#   'JJR': 2},
#  'apprehensions': {'NNS': 2},
#  "n't": {'RB': 2004},
#  'help': {'VB': 260, 'NN': 288, 'VBP': 37, 'VBZ': 3, 'VBN': 1},
#  'sting': {'VBG': 50, 'NN': 50, 'VB': 3},
#  'clinging': {'VBG': 58, 'NN': 12},
#  'moment': {'NN': 993},
#  'before': {'IN': 3296, 'RB': 248, 'VBP': 1, 'NN': 9, 'VB': 4},
#  'ground': {'NN': 1173,
#   'VBN': 3,
#   'VB': 6,
#   'JJ': 2,
#   'VBP': 5,
#   'VBZ': 1,
#   'VBD': 8},
#  'gold': {'NN': 1077, 'JJ': 111, 'VBN': 5, 'VB': 12, 'VBD': 3, 'VBP': 3},
#  'true': {'JJ': 1101},
#  'trick': {'JJ': 16, 'VB': 9, 'NN': 107, 'VBP': 1, 'VBN': 1},
#  'evening': {'VBG': 283, 'NN': 479, 'JJ': 11, 'VB': 2},
#  'plays': {'NNS': 60, 'VBZ': 82, 'JJ': 1, 'VBP': 1},
#  'roses': {'NNS': 311, 'VBZ': 22},
#  'curls': {'VBD': 4,
#   'VBZ': 8,
#   'JJ': 6,
#   'NN': 42,
#   'NNS': 42,
#   'VB': 3,
#   'VBP': 1},
#  'herself': {'PRP': 349, 'NN': 51, 'VB': 34, 'JJ': 2, 'RB': 1},
#  'stinger': {'JJR': 1, 'NN': 3},
#  'twitching': {'NN': 5, 'VBG': 30, 'JJ': 1},
#  'gilt': {'NN': 29, 'JJ': 15, 'VBP': 2, 'VBN': 2},
#  'wings': {'NNS': 925, 'VBZ': 6, 'JJ': 1},
#  'folded': {'VBD': 78, 'VBN': 59, 'JJ': 32},
#  'few': {'JJ': 967},
#  'weeks': {'NNS': 209},
#  'pain': {'NN': 936, 'VBP': 23, 'JJ': 11, 'VB': 32, 'VBN': 3, 'RB': 6},
#  'subsided': {'VBD': 8, 'VBN': 2},
#  'hardly': {'RB': 270, 'JJ': 2, 'NN': 1},
#  'wits': {'NNS': 79, 'VBZ': 3},
#  'buzz': {'VB': 5, 'NN': 42, 'VBP': 7, 'IN': 2},
#  'warning': {'NN': 65, 'VBG': 47, 'VBP': 1},
#  'either': {'DT': 221,
#   'NN': 5,
#   'CC': 148,
#   'RB': 75,
#   'VBP': 2,
#   'VB': 7,
#   'IN': 1},
#  'richness': {'NN': 17, 'JJ': 2},
#  'petals': {'NNS': 191, 'VBZ': 1},
#  'cupping': {'VBG': 16, 'NN': 1},
#  'devastating': {'VBG': 2, 'NN': 1},
#  'force': {'NN': 368, 'VBP': 16, 'VB': 30, 'JJ': 1, 'VBN': 1, 'VBZ': 1},
#  'crushing': {'VBG': 22, 'NN': 4},
#  'scent': {'NN': 219, 'JJ': 32, 'VBD': 2, 'VB': 4, 'VBP': 2},
#  'mortally': {'RB': 6},
#  'threatened': {'VBD': 24, 'VBN': 11, 'JJ': 3},
#  'wholly': {'RB': 108},
#  'unaware': {'JJ': 23, 'VBP': 2, 'NN': 22, 'VB': 2},
#  'daily': {'JJ': 204, 'RB': 55, 'VB': 3, 'NN': 1},
#  'alone': {'RB': 1499, 'JJ': 41, 'NN': 33, 'VBP': 10, 'VB': 12, 'CD': 2},
#  'last': {'JJ': 2840},
#  'seems': {'VBZ': 742},
#  'act': {'NN': 240, 'VB': 68, 'VBP': 9, 'JJ': 11, 'VBZ': 1, 'IN': 1},
#  'speak': {'VB': 531,
#   'VBP': 192,
#   'NN': 223,
#   'JJ': 53,
#   'MD': 1,
#   'VBN': 2,
#   'VBD': 3,
#   'VBZ': 3,
#   'CC': 2},
#  'ill': {'NN': 169,
#   'JJ': 102,
#   'RB': 26,
#   'VB': 54,
#   'IN': 2,
#   'VBP': 12,
#   'VBN': 4,
#   'VBZ': 1},
#  'jack': {'NN': 141, 'VB': 3, 'JJ': 1, 'CC': 1, 'RP': 1, 'VBP': 1},
#  'flick': {'NN': 26, 'VB': 3, 'JJ': 10, 'VBP': 5},
#  'rarely': {'RB': 77},
#  'scar': {'NN': 79, 'VB': 2, 'VBN': 1, 'VBP': 2, 'VBZ': 2},
#  'made': {'VBD': 1683, 'VBN': 1508, 'VB': 4, 'NN': 6, 'JJ': 1},
#  'cheek': {'JJ': 46, 'NN': 233, 'VB': 4, 'VBP': 1},
#  'summer': {'NN': 1259},
#  'lake': {'NN': 430, 'VBP': 20, 'JJ': 62, 'VB': 16, 'VBZ': 1, 'JJR': 1},
#  'wo': {'MD': 146},
#  'whose': {'WP$': 2282},
#  'freckles': {'NNS': 18},
#  'gangly': {'RB': 7},
#  'legs': {'NNS': 393,
#   'JJ': 125,
#   'VBZ': 17,
#   'NN': 109,
#   'JJR': 1,
#   'RB': 3,
#   'FW': 1,
#   'CC': 3,
#   'VBP': 1,
#   'VB': 3,
#   'PDT': 1,
#   'VBN': 2,
#   'VBD': 1,
#   'IN': 1},
#  'gone': {'VBN': 1629},
#  'drained': {'JJ': 4, 'VBN': 35, 'VBD': 24},
#  'saw': {'VBD': 1786,
#   'NN': 135,
#   'JJ': 16,
#   'VBN': 8,
#   'VB': 4,
#   'NNS': 1,
#   'VBZ': 1,
#   'CC': 1},
#  "'d": {'MD': 4911,
#   'VBD': 115,
#   'NNS': 184,
#   'NN': 171,
#   'CD': 426,
#   'POS': 235,
#   'NNP': 186,
#   'RB': 21,
#   'IN': 29,
#   'UH': 10,
#   'PRP': 27,
#   'JJ': 34,
#   'RBS': 1,
#   'CC': 31,
#   "''": 36,
#   'VBN': 29,
#   'VBZ': 6,
#   'VB': 13,
#   'RP': 3,
#   'JJR': 1,
#   'FW': 5},
#  'done': {'VBN': 1031},
#  'sharp': {'JJ': 353},
#  'nonchalantly': {'RB': 2},
#  'skipped': {'VBD': 15, 'VBN': 4, 'NN': 1},
#  'well': {'RB': 2033,
#   'NN': 219,
#   'VB': 6,
#   'VBD': 1,
#   'WDT': 1,
#   'UH': 11,
#   'VBP': 11,
#   'IN': 1,
#   'NNS': 1},
#  'somewhat': {'RB': 82, 'NN': 2, 'JJ': 1, 'NNS': 1, 'VBN': 1, 'FW': 1},
#  'lie': {'VB': 280,
#   'RB': 21,
#   'VBP': 276,
#   'NN': 360,
#   'JJ': 50,
#   'FW': 6,
#   'RBS': 1,
#   'VBZ': 29,
#   'VBD': 10,
#   'JJR': 5,
#   'IN': 4,
#   'RBR': 8,
#   'VBN': 3,
#   'CC': 6,
#   'NNS': 7,
#   'JJS': 1},
#  'dock': {'NN': 68, 'VBP': 1},
#  'while': {'IN': 2635, 'NN': 369, 'JJ': 3, 'VB': 2},
#  'friends': {'NNS': 758, 'VBZ': 31, 'VB': 1, 'JJ': 1},
#  'bent': {'VBP': 20,
#   'NN': 234,
#   'JJ': 101,
#   'VBD': 25,
#   'IN': 1,
#   'VB': 6,
#   'VBN': 9},
#  'wiped': {'VBD': 47, 'VBN': 7, 'NN': 1},
#  'sandy': {'JJ': 40, 'NN': 12, 'PDT': 1},
#  'towel': {'NN': 59, 'VBZ': 1, 'VB': 1},
#  'wound': {'NN': 308,
#   'VBN': 8,
#   'VB': 29,
#   'IN': 27,
#   'VBD': 24,
#   'VBP': 10,
#   'JJ': 10,
#   'VBZ': 1,
#   'RB': 1,
#   'JJS': 1},
#  'proved': {'VBD': 44, 'VBN': 21, 'JJ': 1},
#  'find': {'VB': 1205,
#   'VBP': 552,
#   'NN': 38,
#   'JJ': 4,
#   'NNS': 5,
#   'IN': 11,
#   'JJR': 1,
#   'RB': 2,
#   'RBR': 1},
#  'went': {'VBD': 1430},
#  'corps': {'NN': 15, 'VBN': 1, 'JJ': 1, 'VBZ': 1},
#  'fought': {'VBN': 46,
#   'VBD': 70,
#   'JJ': 11,
#   'VBP': 11,
#   'NN': 20,
#   'RB': 2,
#   'MD': 1},
#  'wars': {'NNS': 177, 'VBZ': 3},
#  'retired': {'VBN': 11, 'JJ': 12, 'VBD': 20},
#  'lived': {'VBD': 435, 'VBN': 171, 'JJ': 8},
#  'than': {'IN': 3866},
#  'year': {'NN': 1180},
#  'tender': {'NN': 315, 'JJR': 3, 'JJ': 10, 'VBP': 7, 'VB': 9, 'VBN': 1},
#  'heart': {'NN': 3363},
#  'gave': {'VBD': 859},
#  'spruce': {'NN': 40, 'VB': 4, 'VBP': 2, 'JJ': 1},
#  'twills': {'NNS': 1},
#  'uppermost': {'JJ': 3},
#  'tier': {'JJR': 6, 'NN': 4, 'JJ': 1, 'VBP': 1},
#  'leaves': {'NNS': 1031, 'VBZ': 478, 'VBN': 1, 'VB': 1},
#  'song': {'NN': 1247,
#   'JJ': 86,
#   'VBD': 5,
#   'RB': 23,
#   'VB': 8,
#   'JJR': 1,
#   'VBN': 1,
#   'VBP': 2},
#  'bird': {'JJ': 22, 'NN': 916, 'VB': 4, 'RB': 4, 'IN': 1, 'VBZ': 1, 'VBD': 2},
#  'squeaky': {'JJ': 6, 'NN': 3},
#  'lock': {'NN': 103,
#   'VBP': 14,
#   'VB': 16,
#   'JJ': 3,
#   'VBZ': 8,
#   'IN': 1,
#   'JJR': 1},
#  'canoe': {'NN': 42, 'JJ': 1},
#  'oar': {'NN': 36, 'JJ': 10, 'IN': 1, 'VB': 1, 'FW': 1, 'PRP': 1, 'NNS': 1},
#  'followed': {'VBN': 86, 'VBD': 185, 'NN': 1},
#  'startling': {'VBG': 16, 'JJ': 5, 'NN': 2},
#  'chirps': {'NN': 7, 'VBZ': 3, 'NNS': 1, 'VBD': 1, 'JJ': 1},
#  'sailboats': {'NNS': 7},
#  'think': {'VBP': 1429, 'VB': 883, 'NN': 267, 'JJ': 2, 'IN': 4, 'CC': 1},
#  'kind': {'NN': 1199},
#  'god': {'NN': 2486,
#   'JJ': 371,
#   'FW': 17,
#   'VBN': 19,
#   'VB': 220,
#   'VBZ': 27,
#   'NNS': 86,
#   'VBP': 59,
#   'VBD': 13,
#   'NNP': 1,
#   'RB': 8,
#   'RBR': 1,
#   'PRP': 1,
#   'PDT': 3,
#   'EX': 1,
#   'CC': 3,
#   'IN': 1},
#  'keeps': {'VBZ': 300,
#   'VB': 5,
#   'NNS': 60,
#   'VBP': 4,
#   'JJ': 1,
#   'VBN': 1,
#   'NN': 1},
#  'himself': {'PRP': 913},
#  'secret': {'JJ': 443, 'NN': 93, 'VB': 2, 'VBD': 2, 'VBP': 1, 'VBZ': 2},
#  'seek': {'VB': 174,
#   'JJ': 28,
#   'NN': 61,
#   'VBP': 126,
#   'VBD': 2,
#   'VBZ': 3,
#   'RB': 1,
#   'CC': 1,
#   'MD': 1},
#  'children': {'NNS': 1554},
#  'beetle': {'JJ': 19, 'NN': 33, 'VB': 2},
#  'scuttling': {'VBG': 6, 'NN': 1, 'JJ': 1},
#  'grass': {'NN': 1074, 'VB': 7, 'JJ': 5, 'VBN': 2, 'VBP': 1},
#  'hidden': {'NN': 85,
#   'VBN': 117,
#   'JJ': 173,
#   'PRP': 2,
#   'UH': 3,
#   'VB': 9,
#   'VBP': 10,
#   'RB': 4,
#   'VBZ': 6,
#   'RBR': 1,
#   'VBD': 1},
#  'plain': {'NN': 317,
#   'JJ': 35,
#   'RB': 17,
#   'VB': 21,
#   'VBN': 5,
#   'VBP': 21,
#   'VBZ': 2},
#  'sight': {'NN': 683,
#   'VBD': 16,
#   'JJ': 63,
#   'RB': 2,
#   'VB': 22,
#   'VBN': 8,
#   'PDT': 1},
#  'pointed': {'JJ': 30, 'VBN': 33, 'VBD': 92},
#  'drunk': {'NN': 169,
#   'VBN': 19,
#   'JJ': 53,
#   'RB': 8,
#   'NNS': 1,
#   'VBP': 6,
#   'VB': 9,
#   'IN': 2,
#   'VBZ': 5,
#   'VBD': 1},
#  'party': {'NN': 212},
#  'showing': {'VBG': 103, 'NN': 7, 'JJ': 1},
#  'gun': {'NN': 225, 'JJ': 14, 'VBN': 1, 'VB': 1},
#  'collection': {'NN': 58},
#  'bed': {'NN': 1290,
#   'VBD': 48,
#   'VB': 49,
#   'JJ': 28,
#   'VBN': 8,
#   'RB': 1,
#   'VBZ': 1,
#   'NNS': 1},
#  'nettles': {'NNS': 22, 'VBZ': 2},
#  'really': {'RB': 736},
#  'girl': {'NN': 963,
#   'JJ': 109,
#   'VB': 6,
#   'VBP': 4,
#   'NNS': 8,
#   'FW': 1,
#   'VBD': 1},
#  'weeping': {'VBG': 178, 'NN': 51, 'JJ': 2},
#  'closet': {'NN': 116},
#  'stepfather': {'NN': 7, 'JJR': 1},
#  'boots': {'NNS': 204, 'VBZ': 3, 'NN': 4, 'JJ': 3, 'VBD': 3, 'RB': 1},
#  'tuft': {'NN': 15, 'JJ': 4},
#  'caught': {'NN': 101, 'VBN': 239, 'VBD': 213, 'VBP': 5, 'JJ': 14},
#  'barbed': {'JJ': 26, 'VBD': 11, 'NN': 15, 'VBN': 8, 'IN': 1},
#  'wire': {'NN': 249, 'VB': 2, 'JJ': 2},
#  'landfill': {'NN': 8},
#  'boy': {'CC': 1,
#   'NN': 1205,
#   'VBZ': 7,
#   'JJ': 71,
#   'UH': 13,
#   'VB': 6,
#   'VBP': 8,
#   'VBN': 4,
#   'FW': 1,
#   'NNS': 3,
#   'IN': 2,
#   'VBD': 2},
#  'shy': {'JJ': 76, 'NN': 47, 'VB': 6, 'VBZ': 3, 'RB': 2, 'NNS': 1},
#  'mouth': {'NN': 1230,
#   'RB': 10,
#   'JJ': 58,
#   'VBP': 8,
#   'VB': 17,
#   'JJS': 1,
#   'NNS': 3,
#   'VBZ': 2,
#   'VBD': 2,
#   'FW': 6,
#   'PDT': 1,
#   'PRP': 1},
#  'playing': {'VBG': 236, 'NN': 72, 'VB': 1},
#  'guitar': {'NN': 91},
#  'picnic': {'NN': 33, 'JJ': 12, 'VB': 2, 'VBP': 1},
#  'table': {'NN': 617, 'JJ': 133, 'VB': 1},
#  'dirt': {'NN': 369,
#   'CC': 1,
#   'VBZ': 3,
#   'NNS': 1,
#   'JJ': 12,
#   'VB': 3,
#   'VBN': 3,
#   'VBP': 1,
#   'RB': 1},
#  'yard': {'NN': 310, 'RB': 29, 'JJ': 6, 'NNP': 3},
#  'slide': {'VBP': 30, 'RB': 10, 'NN': 87, 'VB': 36, 'JJ': 2},
#  'benign': {'NN': 10, 'JJ': 13},
#  'pliable': {'JJ': 5},
#  'quills': {'NNS': 14},
#  'pressed': {'VBD': 70, 'VBN': 117, 'JJ': 16},
#  'smooth': {'RB': 10,
#   'JJ': 200,
#   'CC': 35,
#   'NN': 42,
#   'VB': 18,
#   'VBZ': 3,
#   'VBN': 8,
#   'VBP': 9,
#   'FW': 2,
#   'PDT': 6,
#   'DT': 3,
#   'NNS': 2,
#   'VBD': 1},
#  'tail': {'NN': 246, 'JJ': 3, 'VB': 4, 'VBP': 2, 'EX': 1},
#  'stiffens': {'VBZ': 7, 'NNS': 5},
#  'barbs': {'NN': 5, 'JJ': 1, 'NNS': 1},
#  'thousands': {'NNS': 159},
#  'quick': {'JJ': 316,
#   'RB': 24,
#   'NN': 79,
#   'VBD': 1,
#   'VBP': 6,
#   'VB': 7,
#   'VBZ': 2},
#  'retorts': {'NNS': 3},
#  'guarded': {'JJ': 7, 'VBN': 14, 'VBD': 10},
#  'remembers': {'NNS': 46, 'VBZ': 59, 'VB': 1},
#  'being': {'VBG': 1861},
#  'soft': {'JJ': 973, 'NN': 6, 'RB': 1, 'VBZ': 4, 'VBD': 2, 'VBP': 3, 'VB': 1},
#  'once': {'RB': 2685, 'IN': 141, 'JJ': 2, 'VB': 7, 'NN': 10},
#  'planted': {'VBD': 56, 'VBN': 95, 'JJ': 6},
#  'tree': {'NN': 1213,
#   'JJ': 321,
#   'VBP': 31,
#   'VBD': 3,
#   'VB': 12,
#   'IN': 1,
#   'RB': 2,
#   'NNS': 1,
#   'CD': 1,
#   'EX': 1,
#   'VBN': 1,
#   'VBZ': 2},
#  'memory': {'NN': 814, 'VB': 10, 'JJ': 1},
#  'become': {'VBN': 189,
#   'VB': 313,
#   'VBP': 144,
#   'NN': 45,
#   'JJ': 19,
#   'VBZ': 3,
#   'FW': 1,
#   'VBD': 1,
#   'RB': 2,
#   'IN': 2},
#  'transparent': {'JJ': 47, 'NN': 65},
#  'slicing': {'VBG': 26, 'NN': 4},
#  'apples': {'NNS': 194, 'VB': 1, 'VBZ': 2},
#  'grandmother': {'NN': 221, 'RB': 8, 'JJ': 9, 'NNS': 1, 'VB': 1, 'VBP': 1},
#  'yellow': {'JJ': 759,
#   'NN': 130,
#   'VBP': 11,
#   'CC': 4,
#   'VB': 17,
#   'IN': 5,
#   'NNP': 1,
#   'RB': 1,
#   "''": 1,
#   'PRP': 1},
#  'bowl': {'NN': 238, 'VBP': 2, 'JJ': 2, 'VB': 2},
#  'better': {'RBR': 249,
#   'JJR': 694,
#   'RB': 56,
#   'VBP': 5,
#   'NN': 8,
#   'VB': 11,
#   'CC': 1},
#  'fruit': {'NN': 504, 'VBP': 4, 'JJ': 9, 'VB': 8},
#  'today': {'NN': 679},
#  'polishes': {'VBZ': 3, 'NNS': 4},
#  'thumb': {'NN': 114, 'JJ': 34, 'VB': 6, 'VBP': 4, 'VBZ': 1},
#  'holds': {'VBZ': 362},
#  'says': {'VBZ': 1540},
#  'hesitation': {'NN': 16},
#  'oh': {'UH': 740,
#   'VBZ': 24,
#   'IN': 104,
#   'NN': 225,
#   'JJ': 148,
#   'VBP': 12,
#   'VB': 16,
#   'VBN': 3,
#   'RB': 20,
#   'MD': 14,
#   'CC': 5,
#   'RP': 1,
#   'NNS': 5,
#   'FW': 3,
#   'VBD': 4,
#   'PRP': 4},
#  'fragile': {'JJ': 92, 'NN': 25, 'RB': 7, 'IN': 1, 'VBP': 1},
#  'almost': {'RB': 971},
#  'core': {'NN': 101, 'RB': 2, 'JJ': 2},
#  'longer': {'RBR': 268, 'RB': 178, 'JJR': 199, 'NN': 11, 'VB': 1},
#  'roll': {'VB': 65,
#   'VBP': 92,
#   'NN': 149,
#   'JJ': 3,
#   'VBN': 3,
#   'VBD': 1,
#   'VBG': 1},
#  'crust': {'NN': 68, 'JJ': 3, 'VB': 2, 'VBZ': 1, 'VBP': 1},
#  'sweeten': {'VB': 13, 'VBP': 3, 'JJ': 5},
#  'sauce': {'NN': 36, 'VBP': 7, 'JJ': 1, 'VB': 2},
#  'desire': {'NN': 605,
#   'VBP': 26,
#   'JJ': 4,
#   'VB': 34,
#   'RP': 1,
#   'VBN': 1,
#   'VBZ': 1},
#  'clear': {'JJ': 855, 'VBP': 23, 'VB': 41, 'RB': 3, 'NN': 3},
#  'pie': {'JJ': 7, 'NN': 67},
#  'wants': {'VBZ': 494},
#  'slice': {'NN': 63, 'VB': 13, 'RB': 1, 'VBP': 4, 'JJ': 3},
#  'close': {'RB': 477, 'VBP': 53, 'JJ': 279, 'VB': 108, 'NN': 84, 'VBD': 4},
#  'dare': {'NN': 104, 'VB': 56, 'VBP': 59, 'VBZ': 9, 'JJ': 12},
#  'cathedral': {'JJ': 55, 'NN': 27},
#  'seeds': {'NNS': 215, 'VBP': 1, 'VBZ': 3},
#  'remember': {'VBP': 450, 'VB': 752, 'NN': 109},
#  'need': {'VBP': 496,
#   'VB': 166,
#   'NN': 388,
#   'JJ': 15,
#   'RB': 3,
#   'VBN': 17,
#   'MD': 26,
#   'DT': 2,
#   'FW': 1},
#  'entrance': {'NN': 88, 'JJ': 1},
#  'complex': {'JJ': 46, 'VB': 1, 'NN': 12},
#  'led': {'VBN': 129, 'VBD': 202, 'JJ': 2, 'VB': 1},
#  'onto': {'IN': 366, 'RB': 1, 'NN': 2, 'JJ': 2, 'RP': 2},
#  'upended': {'JJ': 4},
#  'couch': {'JJ': 55, 'NN': 67, 'VB': 4, 'RB': 1, 'VBP': 1},
#  'tilted': {'VBN': 17, 'JJ': 13, 'VBD': 19},
#  'ditch': {'NN': 102, 'JJ': 1, 'VBP': 2, 'VB': 2},
#  'washing': {'JJ': 4, 'VBG': 84, 'NN': 23},
#  'machine': {'NN': 267},
#  'gleamed': {'VBD': 24, 'VBN': 10},
#  'avocado': {'JJ': 5, 'NN': 15},
#  'pine': {'NN': 270, 'JJ': 34, 'VB': 20, 'VBP': 5},
#  'needles': {'NNS': 140},
#  'turned': {'VBD': 744, 'JJ': 22, 'VBN': 204},
#  'trail': {'NN': 190, 'VBP': 9, 'JJ': 11, 'VB': 5},
#  'cul': {'NN': 15},
#  'de': {'IN': 262,
#   'FW': 245,
#   'VBZ': 1,
#   'VB': 10,
#   'VBP': 3,
#   'NN': 5,
#   'JJ': 5,
#   'VBN': 1,
#   'RB': 1,
#   'NNP': 1},
#  'sac': {'FW': 2, 'NN': 13, 'JJ': 1},
#  'bright': {'JJ': 946,
#   'VB': 4,
#   'NN': 177,
#   'VBD': 88,
#   'VBN': 33,
#   'RB': 14,
#   'MD': 1,
#   'CC': 1,
#   'VBP': 1,
#   'EX': 1},
#  'brick': {'NN': 128, 'JJ': 15, 'FW': 1, 'RB': 1, 'VB': 1, 'VBP': 1},
#  'far': {'RB': 1996},
#  'dared': {'VBD': 52, 'VBN': 15, 'JJ': 1, 'VBP': 1},
#  'mower': {'JJR': 11, 'NN': 25},
#  'might': {'MD': 2119},
#  'ask': {'VB': 443,
#   'VBP': 205,
#   'NN': 126,
#   'IN': 18,
#   'JJ': 16,
#   'VBZ': 7,
#   'RB': 1,
#   'RP': 1,
#   'VBD': 5,
#   'CC': 1,
#   'NNS': 1},
#  '``': {'``': 3368},
#  'whadda': {'NN': 1, 'VB': 1},
#  'boys': {'VBP': 6,
#   'NNS': 430,
#   'JJ': 16,
#   'NN': 7,
#   'VBN': 3,
#   'VBZ': 40,
#   'VB': 3,
#   'PDT': 1,
#   'IN': 3,
#   'RB': 1,
#   'RP': 1},
#  "''": {"''": 1809},
#  'answer': {'VB': 160,
#   'NN': 274,
#   'JJR': 39,
#   'VBP': 48,
#   'IN': 5,
#   'VBD': 1,
#   'VBZ': 4,
#   'RP': 3,
#   'RB': 2,
#   'CC': 2},
#  'loved': {'VBD': 533, 'VBN': 259, 'JJ': 50, 'NN': 2},
#  'name': {'NN': 1838,
#   'VB': 95,
#   'VBZ': 1,
#   'VBP': 28,
#   'JJ': 5,
#   'IN': 3,
#   'CC': 1,
#   'RB': 1},
#  'white': {'JJ': 3517},
#  'hall': {'NN': 295, 'VBZ': 1, 'JJ': 7, 'DT': 1, 'VB': 1, 'PDT': 1},
#  'imagined': {'VBD': 75, 'JJ': 22, 'VBN': 46, 'VB': 1},
#  'interior': {'NN': 46, 'JJ': 49},
#  'stretch': {'NN': 92, 'VBP': 35, 'VB': 51, 'VBZ': 2, 'JJ': 2, 'VBD': 1},
#  'marble': {'JJ': 150, 'NN': 75, 'VB': 3},
#  'perfect': {'JJ': 475, 'NN': 80, 'VB': 7, 'VBP': 25},
#  'wall': {'NN': 985,
#   'VB': 11,
#   'JJ': 26,
#   'VBP': 3,
#   'VBZ': 1,
#   'DT': 1,
#   'PDT': 1},
#  'adorned': {'VBN': 22, 'JJ': 2, 'VBD': 22},
#  'smiling': {'VBG': 198, 'NN': 31, 'JJ': 3},
#  'photos': {'NNS': 31, 'NN': 19, 'JJ': 3},
#  'family': {'NN': 490},
#  'halls': {'NNS': 101, 'VB': 1, 'VBZ': 2},
#  'brailled': {'VBN': 3, 'VBD': 1},
#  'nail': {'JJ': 21, 'NN': 72, 'VB': 9, 'IN': 1, 'VBP': 2, 'CC': 1, 'VBZ': 1},
#  'holes': {'NNS': 204, 'VBZ': 7},
#  'former': {'JJ': 130},
#  'tenants': {'NNS': 19},
#  'spackled': {'JJ': 2, 'VBN': 1, 'VBD': 1},
#  'rounds': {'NNS': 44, 'VBZ': 14},
#  'fists': {'NNS': 99, 'JJ': 1},
#  'does': {'VBZ': 1685},
#  'longing': {'VB': 2, 'VBG': 73, 'NN': 114},
#  'clarify': {'VB': 10, 'VBP': 1, 'VBZ': 1},
#  'tommy': {'NN': 7, 'JJ': 2},
#  'wearing': {'VBG': 263, 'NN': 6},
#  'war': {'NN': 1037},
#  'ii': {'NN': 237, 'VBP': 7, 'JJ': 112, 'VB': 27, 'VBZ': 4, 'IN': 1},
#  'trenching': {'VBG': 1},
#  'tool': {'NN': 42, 'VB': 2},
#  'danny': {'NN': 11, 'NNS': 1, 'JJ': 5},
#  'older': {'JJR': 212, 'NN': 6, 'IN': 2, 'VBP': 4},
#  'other': {'JJ': 3594},
#  'parents': {'NNS': 301, 'VBZ': 1},
#  'died': {'VBD': 655, 'VBN': 173, 'NN': 1, 'VB': 1},
#  'recliner': {'NN': 5, 'VBP': 1},
#  'sunny': {'JJ': 100, 'NN': 14, 'VBD': 1, 'VB': 1},
#  'afternoon': {'NN': 529},
#  'baseball': {'NN': 63},
#  'duke': {'NN': 61, 'JJ': 8, 'VB': 1},
#  'stole': {'VBD': 30, 'VB': 7, 'JJ': 21, 'NN': 30, 'VBZ': 4, 'VBP': 21},
#  'car': {'NN': 799},
#  'crashed': {'VBD': 28, 'VBN': 11, 'VB': 1},
#  'knew': {'VBD': 1269,
#   'JJ': 11,
#   'VBP': 36,
#   'VBN': 20,
#   'NNS': 23,
#   'VB': 52,
#   'NN': 38,
#   'FW': 12,
#   'NNP': 2,
#   'CC': 1,
#   'RB': 5,
#   'VBZ': 2,
#   'IN': 1,
#   'MD': 1},
#  'posing': {'VBG': 21, 'NN': 4},
#  'someone': {'NN': 1165},
#  'smile': {'NN': 417,
#   'JJ': 93,
#   'VB': 73,
#   'RB': 11,
#   'VBP': 51,
#   'VBZ': 1,
#   'IN': 1},
#  'latch': {'JJ': 2, 'NN': 19},
#  'key': {'JJ': 56, 'NN': 137, 'VB': 3, 'VBD': 1},
#  ...}

# %%
def POS_prob(word, dic, a = 0):
    counts_dic = dic[word]
    
    if(not (((list(counts_dic.values())[0])<1)) ):
        total_counts = 0
        for POS_tag,Count in list(counts_dic.items()):
            total_counts = total_counts+Count
        
        items = list(counts_dic.items())
        alpha = a*total_counts
        for POS_tag,Count in items:
            counts_dic[POS_tag] = ((Count+alpha)/(total_counts + alpha*len(items)))

# %%
pos_dicts["along"]
# Out:
# {'IN': 1017, 'RB': 262, 'JJ': 3, 'NN': 6, 'VB': 7, 'RP': 13, 'NNS': 1}

# %%
list(pos_dicts["garlic"].items())
# Out:
# [('JJ', 0.6944444444444444),
#  ('NN', 0.2777777777777778),
#  ('NNS', 0.027777777777777776)]

# %%
nextPOSWord("along","that")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-b2e111b89f09> in <module>
# ----> 1 nextPOSWord("along","that")
#
# TypeError: nextPOSWord() missing 4 required positional arguments: 'words_nGram', 'POS_nGram', 'POS_dic_words', and 'n'
